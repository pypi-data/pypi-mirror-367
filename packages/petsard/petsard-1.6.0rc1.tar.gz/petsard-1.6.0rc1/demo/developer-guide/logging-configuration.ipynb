# %% [markdown]
# # Environment setting / 環境設定
# Logging Configuration / 日誌設定

# %%
import os
import sys
from pathlib import Path

# 自動載入 utils / Auto-load utils
if "COLAB_GPU" in os.environ:
    url = "https://raw.githubusercontent.com/nics-tw/petsard/main/demo/utils.py"
    exec(open(url).read())
else:
    # 靜默搜尋 utils.py / Silent search for utils.py
    current = Path.cwd()
    for _ in range(5):
        if (current / "utils.py").exists():
            sys.path.insert(0, str(current))
            break
        current = current.parent

    # 匯入 utils 模組 / Import utils module
    from utils import quick_setup

# 快速設定 / Quick setup
is_colab, branch, yaml_path = quick_setup(
    yaml_file="logging-configuration.yaml",
    benchmark_data=[
        "adult-income",
    ],
    branch="main",  # 可選，預設為 "main"
)

from petsard import Executor
# Out:
# 🚀 PETsARD v1.5.1
# 📅 2025-07-31 13:03:40 UTC+8
# 📁 Subfolder: developer-guide
# 📄 YAML path: petsard/demo/developer-guide/logging-configuration.yaml
# ⚙️ Configuration content:
# ---
# Executor:
#   log_output_type: both
#   log_level: DEBUG
#   log_dir: demo_logs
#   log_filename: PETsARD_demo_{timestamp}.log
# Loader:
#   log-data:
#     filepath: 'benchmark/adult-income.csv'
# Splitter:
#   demo:
#     num_samples: 1
#     train_split_ratio: 0.8
# Preprocessor:
#   demo:
#     method: 'default'
# Synthesizer:
#   demo:
#     method: 'default'
# Postprocessor:
#   demo:
#     method: 'default'
# Evaluator:
#   demo-diagnostic:
#     method: 'sdmetrics-diagnosticreport'
#   demo-quality:
#     method: 'sdmetrics-qualityreport'
# Reporter:
#   output:
#     method: 'save_data'
#     source: 'Synthesizer'
#   save_report_global:
#     method: 'save_report'
#     granularity: 'global'
# ...

# %% [markdown]
# # Execution and Result / 執行與結果

# %%
exec_case = Executor(config=yaml_path)
exec_case.run()
# Out:
# 2025-07-31 13:05:26,733 - PETsARD.Executor      - _get_config       - INFO     - Logger reconfigured with settings from YAML
# 2025-07-31 13:05:26,733 - PETsARD.Loader        - __init__          - INFO     - Initializing Loader
# 2025-07-31 13:05:26,734 - PETsARD.Loader        - __init__          - DEBUG    - Loader parameters - filepath: benchmark/adult-income.csv, method: None, column_types: None
# 2025-07-31 13:05:26,734 - PETsARD.LoaderConfig  - __post_init__     - DEBUG    - Initializing LoaderConfig
# 2025-07-31 13:05:26,734 - PETsARD.LoaderConfig  - __post_init__     - DEBUG    - File path information - dir: benchmark, name: adult-income, ext: .csv, ext code: 1
# 2025-07-31 13:05:26,735 - PETsARD.Loader        - __init__          - DEBUG    - LoaderConfig successfully initialized
# 2025-07-31 13:05:26,735 - PETsARD.Synthesizer   - __init__          - INFO     - Initializing Synthesizer with method: default, sample_num_rows: None
# 2025-07-31 13:05:26,736 - PETsARD.SynthesizerConfig - __post_init__     - DEBUG    - Initializing SynthesizerConfig
# 2025-07-31 13:05:26,736 - PETsARD.SynthesizerConfig - __post_init__     - DEBUG    - Mapped synthesizing method 'default' to code 1
# 2025-07-31 13:05:26,736 - PETsARD.SynthesizerConfig - __post_init__     - INFO     - SynthesizerConfig initialized with method: default, syn_method: sdv-single_table-gaussiancopula
# 2025-07-31 13:05:26,736 - PETsARD.Synthesizer   - __init__          - DEBUG    - SynthesizerConfig successfully initialized
# 2025-07-31 13:05:26,737 - PETsARD.Synthesizer   - __init__          - DEBUG    - No additional parameters provided
# 2025-07-31 13:05:26,737 - PETsARD.Synthesizer   - __init__          - INFO     - Synthesizer initialization completed
# 2025-07-31 13:05:26,737 - PETsARD.Evaluator     - __init__          - INFO     - Initializing Evaluator with method: sdmetrics-diagnosticreport
# 2025-07-31 13:05:26,737 - PETsARD.EvaluatorConfig - __post_init__     - DEBUG    - Initializing EvaluatorConfig
# 2025-07-31 13:05:26,738 - PETsARD.EvaluatorConfig - _init_eval_method - DEBUG    - Mapped evaluating method 'sdmetrics-diagnosticreport' to code EvaluatorMap.SDMETRICS
# 2025-07-31 13:05:26,738 - PETsARD.EvaluatorConfig - _init_eval_method - INFO     - EvaluatorConfig initialized with method: sdmetrics-diagnosticreport, eval_method: sdmetrics-diagnosticreport
# 2025-07-31 13:05:26,739 - PETsARD.Evaluator     - _configure_implementation - DEBUG    - EvaluatorConfig successfully initialized
# 2025-07-31 13:05:26,740 - PETsARD.Evaluator     - _configure_implementation - DEBUG    - No additional parameters provided
# 2025-07-31 13:05:26,740 - PETsARD.Evaluator     - __init__          - INFO     - ≈ initialization completed
# 2025-07-31 13:05:26,740 - PETsARD.Evaluator     - __init__          - INFO     - Initializing Evaluator with method: sdmetrics-qualityreport
# 2025-07-31 13:05:26,741 - PETsARD.EvaluatorConfig - __post_init__     - DEBUG    - Initializing EvaluatorConfig
# 2025-07-31 13:05:26,741 - PETsARD.EvaluatorConfig - _init_eval_method - DEBUG    - Mapped evaluating method 'sdmetrics-qualityreport' to code EvaluatorMap.SDMETRICS
# 2025-07-31 13:05:26,741 - PETsARD.EvaluatorConfig - _init_eval_method - INFO     - EvaluatorConfig initialized with method: sdmetrics-qualityreport, eval_method: sdmetrics-qualityreport
# 2025-07-31 13:05:26,741 - PETsARD.Evaluator     - _configure_implementation - DEBUG    - EvaluatorConfig successfully initialized
# 2025-07-31 13:05:26,741 - PETsARD.Evaluator     - _configure_implementation - DEBUG    - No additional parameters provided
# 2025-07-31 13:05:26,742 - PETsARD.Evaluator     - __init__          - INFO     - ≈ initialization completed
# 2025-07-31 13:05:26,742 - PETsARD.Executor      - run               - INFO     - Starting PETsARD execution workflow
# 2025-07-31 13:05:26,742 - PETsARD.Executor      - run               - INFO     - Executing Loader with log-data
# 2025-07-31 13:05:26,743 - PETsARD.LoaderOp      - run               - INFO     - TIMING_START|LoaderOp|run|1753938326.743078
# 2025-07-31 13:05:26,743 - PETsARD.Status        - _handle_timing_start - DEBUG    - 從 logging 開始計時: LoaderOp_default_run - timing_000001_20250731_130526
# 2025-07-31 13:05:26,743 - PETsARD.LoaderOp      - run               - INFO     - Starting LoaderOp execution
# 2025-07-31 13:05:26,743 - PETsARD.LoaderOp      - _run              - DEBUG    - Starting data loading process
# 2025-07-31 13:05:26,744 - PETsARD.Loader        - load              - INFO     - Loading data from benchmark/adult-income.csv
# 2025-07-31 13:05:26,744 - PETsARD.Loader        - load              - INFO     - Loading data using file extension: .csv
# 2025-07-31 13:05:26,744 - PETsARD.Loader        - load              - DEBUG    - Using inferred headers
# 2025-07-31 13:05:26,801 - PETsARD.Loader        - load              - INFO     - Successfully loaded data with shape: (48842, 15)
# 2025-07-31 13:05:26,801 - PETsARD.Loader        - load              - INFO     - Building schema configuration
# 2025-07-31 13:05:26,802 - PETsARD.Loader        - load              - INFO     - Building schema schema from dataframe
# 2025-07-31 13:05:26,943 - PETsARD.Loader        - load              - DEBUG    - Built schema with 15 fields
# 2025-07-31 13:05:26,943 - PETsARD.Loader        - load              - INFO     - Applying schema transformations to optimize data
# 2025-07-31 13:05:26,962 - PETsARD.Loader        - load              - DEBUG    - Schema transformations applied successfully
# 2025-07-31 13:05:26,962 - PETsARD.Loader        - load              - INFO     - Data loading completed successfully
# 2025-07-31 13:05:26,963 - PETsARD.LoaderOp      - _run              - DEBUG    - Using SchemaMetadata from Metadater
# 2025-07-31 13:05:26,963 - PETsARD.LoaderOp      - _run              - DEBUG    - Data loading completed
# 2025-07-31 13:05:26,963 - PETsARD.LoaderOp      - run               - INFO     - TIMING_END|LoaderOp|run|1753938326.9636962|0.2206120491027832
# 2025-07-31 13:05:26,963 - PETsARD.Status        - _handle_timing_end - DEBUG    - 從 logging 結束計時: LoaderOp_default_run - 耗時: 0:00:00
# 2025-07-31 13:05:26,964 - PETsARD.LoaderOp      - run               - INFO     - Completed LoaderOp execution (elapsed: 0:00:00)
# 2025-07-31 13:05:26,964 - PETsARD.Status        - _track_metadata_change - DEBUG    - 追蹤變更: change_000001_20250731_130526 - create schema
# 2025-07-31 13:05:26,964 - PETsARD.Status        - _create_snapshot  - DEBUG    - 建立快照: snapshot_000001_20250731_130526 for Loader[log-data]
# 2025-07-31 13:05:26,964 - PETsARD.Status        - put               - INFO     - 狀態已更新: Loader[log-data] - 快照數量: 1
# 2025-07-31 13:05:26,965 - PETsARD.Executor      - run               - INFO     - Executing Splitter with demo_[1-1]
# 2025-07-31 13:05:26,965 - PETsARD.SplitterOp    - run               - INFO     - TIMING_START|SplitterOp|run|1753938326.965464
# 2025-07-31 13:05:26,965 - PETsARD.Status        - _handle_timing_start - DEBUG    - 從 logging 開始計時: SplitterOp_default_run - timing_000002_20250731_130526
# 2025-07-31 13:05:26,965 - PETsARD.SplitterOp    - run               - INFO     - Starting SplitterOp execution
# 2025-07-31 13:05:26,966 - PETsARD.SplitterOp    - _run              - DEBUG    - Starting data splitting process
# 2025-07-31 13:05:26,980 - PETsARD.SplitterOp    - _run              - DEBUG    - Data splitting completed
# 2025-07-31 13:05:26,981 - PETsARD.SplitterOp    - run               - INFO     - TIMING_END|SplitterOp|run|1753938326.981237|0.015765905380249023
# 2025-07-31 13:05:26,981 - PETsARD.Status        - _handle_timing_end - DEBUG    - 從 logging 結束計時: SplitterOp_default_run - 耗時: 0:00:00
# 2025-07-31 13:05:26,981 - PETsARD.SplitterOp    - run               - INFO     - Completed SplitterOp execution (elapsed: 0:00:00)
# 2025-07-31 13:05:26,982 - PETsARD.Status        - _track_metadata_change - DEBUG    - 追蹤變更: change_000002_20250731_130526 - create schema
# 2025-07-31 13:05:26,987 - PETsARD.Status        - _create_snapshot  - DEBUG    - 建立快照: snapshot_000002_20250731_130526 for Splitter[demo_[1-1]]
# 2025-07-31 13:05:26,988 - PETsARD.Status        - put               - INFO     - 狀態已更新: Splitter[demo_[1-1]] - 快照數量: 2
# 2025-07-31 13:05:26,989 - PETsARD.Executor      - run               - INFO     - Executing Preprocessor with demo
# 2025-07-31 13:05:26,989 - PETsARD.PreprocessorOp - run               - INFO     - TIMING_START|PreprocessorOp|run|1753938326.989772
# 2025-07-31 13:05:26,990 - PETsARD.Status        - _handle_timing_start - DEBUG    - 從 logging 開始計時: PreprocessorOp_default_run - timing_000003_20250731_130526
# 2025-07-31 13:05:26,990 - PETsARD.PreprocessorOp - run               - INFO     - Starting PreprocessorOp execution
# 2025-07-31 13:05:26,990 - PETsARD.PreprocessorOp - _run              - DEBUG    - Initializing processor
# 2025-07-31 13:05:26,990 - PETsARD.Processor     - __init__          - DEBUG    - Initializing Processor
# 2025-07-31 13:05:26,990 - PETsARD.Processor     - __init__          - DEBUG    - Loaded metadata contains 0 fields
# 2025-07-31 13:05:26,991 - PETsARD.Processor     - __init__          - DEBUG    - config is provided:
# 2025-07-31 13:05:26,991 - PETsARD.Processor     - __init__          - DEBUG    - config is provided: {}
# 2025-07-31 13:05:26,991 - PETsARD.Processor     - __init__          - DEBUG    - Schema metadata loaded.
# 2025-07-31 13:05:26,991 - PETsARD.Processor     - _generate_config  - DEBUG    - Starting config generation
# 2025-07-31 13:05:26,992 - PETsARD.Processor     - _generate_config  - DEBUG    - Config generation completed
# 2025-07-31 13:05:26,992 - PETsARD.Processor     - __init__          - DEBUG    - Config loaded.
# 2025-07-31 13:05:26,992 - PETsARD.PreprocessorOp - _run              - DEBUG    - Using default processing sequence
# 2025-07-31 13:05:26,992 - PETsARD.Processor     - fit               - INFO     - MediatorMissing is created.
# 2025-07-31 13:05:26,992 - PETsARD.Processor     - fit               - INFO     - MediatorOutlier is created.
# 2025-07-31 13:05:26,992 - PETsARD.Processor     - fit               - INFO     - MediatorEncoder is created.
# 2025-07-31 13:05:26,993 - PETsARD.Processor     - fit               - INFO     - MediatorScaler is created.
# 2025-07-31 13:05:26,993 - PETsARD.Processor     - fit               - DEBUG    - Fitting sequence generation completed.
# 2025-07-31 13:05:26,993 - PETsARD.Processor     - fit               - INFO     - missing fitting done.
# 2025-07-31 13:05:26,993 - PETsARD.Processor     - fit               - DEBUG    - mediator: MediatorMissing start processing.
# 2025-07-31 13:05:26,993 - PETsARD.Processor     - fit               - INFO     - MediatorMissing fitting done.
# 2025-07-31 13:05:26,994 - PETsARD.Processor     - fit               - INFO     - outlier fitting done.
# 2025-07-31 13:05:26,994 - PETsARD.Processor     - fit               - DEBUG    - mediator: MediatorOutlier start processing.
# 2025-07-31 13:05:26,994 - PETsARD.Processor     - fit               - INFO     - MediatorOutlier fitting done.
# 2025-07-31 13:05:26,994 - PETsARD.Processor     - fit               - INFO     - encoder fitting done.
# 2025-07-31 13:05:26,994 - PETsARD.Processor     - fit               - DEBUG    - mediator: MediatorEncoder start processing.
# 2025-07-31 13:05:26,995 - PETsARD.Processor     - fit               - INFO     - MediatorEncoder fitting done.
# 2025-07-31 13:05:26,995 - PETsARD.Processor     - fit               - INFO     - scaler fitting done.
# 2025-07-31 13:05:26,995 - PETsARD.PreprocessorOp - _run              - DEBUG    - Transforming data
# 2025-07-31 13:05:26,996 - PETsARD.Processor     - transform         - DEBUG    - Starting data transformation, input shape: (39073, 15)
# 2025-07-31 13:05:26,996 - PETsARD.Processor     - transform         - DEBUG    - Executing missing processing
# 2025-07-31 13:05:26,997 - PETsARD.Processor     - transform         - INFO     - missing transformation done.
# 2025-07-31 13:05:26,997 - PETsARD.Processor     - transform         - DEBUG    - mediator: MediatorMissing start transforming.
# 2025-07-31 13:05:26,997 - PETsARD.Processor     - transform         - DEBUG    - before transformation: data shape: (39073, 15)
# 2025-07-31 13:05:26,997 - PETsARD.Processor     - transform         - DEBUG    - after transformation: data shape: (39073, 15)
# 2025-07-31 13:05:26,998 - PETsARD.Processor     - transform         - INFO     - MediatorMissing transformation done.
# 2025-07-31 13:05:26,998 - PETsARD.Processor     - transform         - DEBUG    - Executing outlier processing
# 2025-07-31 13:05:26,998 - PETsARD.Processor     - transform         - INFO     - outlier transformation done.
# 2025-07-31 13:05:26,998 - PETsARD.Processor     - transform         - DEBUG    - mediator: MediatorOutlier start transforming.
# 2025-07-31 13:05:26,998 - PETsARD.Processor     - transform         - DEBUG    - before transformation: data shape: (39073, 15)
# 2025-07-31 13:05:26,999 - PETsARD.Processor     - transform         - DEBUG    - after transformation: data shape: (39073, 15)
# 2025-07-31 13:05:26,999 - PETsARD.Processor     - transform         - INFO     - MediatorOutlier transformation done.
# 2025-07-31 13:05:26,999 - PETsARD.Processor     - transform         - DEBUG    - Executing encoder processing
# 2025-07-31 13:05:26,999 - PETsARD.Processor     - transform         - INFO     - encoder transformation done.
# 2025-07-31 13:05:26,999 - PETsARD.Processor     - transform         - DEBUG    - mediator: MediatorEncoder start transforming.
# 2025-07-31 13:05:26,999 - PETsARD.Processor     - transform         - DEBUG    - before transformation: data shape: (39073, 15)
# 2025-07-31 13:05:26,999 - PETsARD.Metadater     - adjust_metadata_after_processing - DEBUG    - Starting metadata adjustment, mode: global
# 2025-07-31 13:05:27,000 - PETsARD.Metadater     - adjust_metadata_after_processing - DEBUG    - Performing global metadata adjustment
# 2025-07-31 13:05:27,077 - PETsARD.Metadater     - adjust_metadata_after_processing - DEBUG    - Created new schema metadata for transformed data with 15 fields
# 2025-07-31 13:05:27,080 - PETsARD.Processor     - transform         - DEBUG    - after transformation: data shape: (39073, 15)
# 2025-07-31 13:05:27,081 - PETsARD.Processor     - transform         - INFO     - MediatorEncoder transformation done.
# 2025-07-31 13:05:27,081 - PETsARD.Processor     - transform         - DEBUG    - mediator: MediatorScaler start transforming.
# 2025-07-31 13:05:27,088 - PETsARD.Processor     - transform         - DEBUG    - before transformation: data shape: (39073, 15)
# 2025-07-31 13:05:27,091 - PETsARD.Metadater     - adjust_metadata_after_processing - DEBUG    - Starting metadata adjustment, mode: global
# 2025-07-31 13:05:27,092 - PETsARD.Metadater     - adjust_metadata_after_processing - DEBUG    - Performing global metadata adjustment
# 2025-07-31 13:05:27,155 - PETsARD.Metadater     - adjust_metadata_after_processing - DEBUG    - Created new schema metadata for transformed data with 15 fields
# 2025-07-31 13:05:27,156 - PETsARD.Processor     - transform         - DEBUG    - after transformation: data shape: (39073, 15)
# 2025-07-31 13:05:27,156 - PETsARD.Processor     - transform         - INFO     - MediatorScaler transformation done.
# 2025-07-31 13:05:27,156 - PETsARD.Processor     - transform         - DEBUG    - Executing scaler processing
# 2025-07-31 13:05:27,157 - PETsARD.Processor     - transform         - INFO     - scaler transformation done.
# 2025-07-31 13:05:27,157 - PETsARD.PreprocessorOp - run               - INFO     - TIMING_END|PreprocessorOp|run|1753938327.1576939|0.16791796684265137
# 2025-07-31 13:05:27,157 - PETsARD.Status        - _handle_timing_end - DEBUG    - 從 logging 結束計時: PreprocessorOp_default_run - 耗時: 0:00:00
# 2025-07-31 13:05:27,158 - PETsARD.PreprocessorOp - run               - INFO     - Completed PreprocessorOp execution (elapsed: 0:00:00)
# 2025-07-31 13:05:27,158 - PETsARD.Status        - _track_metadata_change - DEBUG    - 追蹤變更: change_000003_20250731_130527 - create schema
# 2025-07-31 13:05:27,158 - PETsARD.Status        - _create_snapshot  - DEBUG    - 建立快照: snapshot_000003_20250731_130527 for Preprocessor[demo]
# 2025-07-31 13:05:27,159 - PETsARD.Status        - put               - INFO     - 狀態已更新: Preprocessor[demo] - 快照數量: 3
# 2025-07-31 13:05:27,159 - PETsARD.Executor      - run               - INFO     - Executing Synthesizer with demo
# 2025-07-31 13:05:27,159 - PETsARD.SynthesizerOp - set_input         - WARNING  - Metadata from Preprocessor has no fields, setting to None
# 2025-07-31 13:05:27,159 - PETsARD.SynthesizerOp - run               - INFO     - TIMING_START|SynthesizerOp|run|1753938327.159949
# 2025-07-31 13:05:27,160 - PETsARD.Status        - _handle_timing_start - DEBUG    - 從 logging 開始計時: SynthesizerOp_default_run - timing_000004_20250731_130527
# 2025-07-31 13:05:27,160 - PETsARD.SynthesizerOp - run               - INFO     - Starting SynthesizerOp execution
# 2025-07-31 13:05:27,160 - PETsARD.SynthesizerOp - _run              - DEBUG    - Starting data synthesizing process
# 2025-07-31 13:05:27,160 - PETsARD.Synthesizer   - create            - INFO     - Creating synthesizer instance
# 2025-07-31 13:05:27,161 - PETsARD.Synthesizer   - create            - DEBUG    - No metadata provided for synthesizer creation
# 2025-07-31 13:05:27,161 - PETsARD.Synthesizer   - _determine_sample_configuration - DEBUG    - Determining sample configuration
# 2025-07-31 13:05:27,161 - PETsARD.Synthesizer   - _determine_sample_configuration - DEBUG    - Using manually specified sample size: 0
# 2025-07-31 13:05:27,161 - PETsARD.Synthesizer   - _determine_sample_configuration - DEBUG    - Using source data as sample source (will be determined during fit)
# 2025-07-31 13:05:27,161 - PETsARD.Synthesizer   - _determine_sample_configuration - INFO     - Sample configuration determined: source=Source data, rows=0
# 2025-07-31 13:05:27,162 - PETsARD.Synthesizer   - create            - DEBUG    - Sample configuration: source=Source data, rows=0
# 2025-07-31 13:05:27,162 - PETsARD.Synthesizer   - create            - DEBUG    - Using synthesizer class: SDVSingleTableSynthesizer
# 2025-07-31 13:05:27,162 - PETsARD.Synthesizer   - create            - DEBUG    - Merged config keys: ['syn_method', 'sample_num_rows']
# 2025-07-31 13:05:27,162 - PETsARD.Synthesizer   - create            - INFO     - Creating SDVSingleTableSynthesizer instance
# 2025-07-31 13:05:27,162 - PETsARD.SDVSingleTableSynthesizer - __init__          - INFO     - Initializing SDVSingleTableSynthesizer with config: {'syn_method': 'sdv-single_table-gaussiancopula', 'sample_num_rows': 0}
# 2025-07-31 13:05:27,163 - PETsARD.SDVSingleTableSynthesizer - __init__          - DEBUG    - No metadata provided, synthesizer will be initialized during fit
# 2025-07-31 13:05:27,163 - PETsARD.Synthesizer   - create            - INFO     - Successfully created SDVSingleTableSynthesizer instance
# 2025-07-31 13:05:27,163 - PETsARD.SynthesizerOp - _run              - DEBUG    - Synthesizing model initialization completed
# 2025-07-31 13:05:27,164 - PETsARD.Synthesizer   - fit               - INFO     - Fitting synthesizer with data shape: (39073, 15)
# 2025-07-31 13:05:27,164 - PETsARD.Synthesizer   - fit               - DEBUG    - Updated sample_num_rows from 0 to 39073
# 2025-07-31 13:05:27,164 - PETsARD.Synthesizer   - fit               - DEBUG    - Updated synthesizer config with sample_num_rows=39073
# 2025-07-31 13:05:27,164 - PETsARD.Synthesizer   - fit               - INFO     - Starting fit process for sdv-single_table-gaussiancopula
# 2025-07-31 13:05:27,164 - PETsARD.SDVSingleTableSynthesizer - fit               - INFO     - Fitting SDVSingleTableSynthesizer
# 2025-07-31 13:05:27,165 - PETsARD.SDVSingleTableSynthesizer - _fit              - INFO     - Fitting synthesizer with data shape: (39073, 15)
# 2025-07-31 13:05:27,165 - PETsARD.SDVSingleTableSynthesizer - _fit              - DEBUG    - Initializing synthesizer in _fit method
# 2025-07-31 13:05:27,165 - PETsARD.SDVMetadataAdapter - create_sdv_metadata - DEBUG    - Creating SDV metadata
# 2025-07-31 13:05:27,165 - PETsARD.SDVMetadataAdapter - create_sdv_metadata - INFO     - Detecting metadata from dataframe with shape (39073, 15)
# 2025-07-31 13:05:27,194 - PETsARD.SDVMetadataAdapter - create_sdv_metadata - DEBUG    - Successfully detected metadata from dataframe
# 2025-07-31 13:05:27,194 - PETsARD.SDVSingleTableSynthesizer - _initialize_impl  - DEBUG    - Initializing synthesizer with method: sdv-single_table-gaussiancopula
# 2025-07-31 13:05:27,194 - PETsARD.SDVSingleTableSynthesizer - _initialize_impl  - DEBUG    - Mapped method code: 3
# 2025-07-31 13:05:27,194 - PETsARD.SDVSingleTableSynthesizer - _initialize_impl  - DEBUG    - Using synthesizer class: GaussianCopulaSynthesizer
# 2025-07-31 13:05:27,198 - PETsARD.SDVSingleTableSynthesizer - _initialize_impl  - DEBUG    - Warning during fit: We strongly recommend saving the metadata using 'save_to_json' for replicability in future SDV versions.
# 2025-07-31 13:05:27,199 - PETsARD.SDVSingleTableSynthesizer - _initialize_impl  - DEBUG    - Successfully created GaussianCopulaSynthesizer instance
# 2025-07-31 13:05:27,199 - PETsARD.SDVSingleTableSynthesizer - _fit              - INFO     - Synthesizer initialized from data
# 2025-07-31 13:05:27,199 - PETsARD.SDVSingleTableSynthesizer - _fit              - DEBUG    - Fitting synthesizer with data
# 2025-07-31 13:05:31,967 - PETsARD.SDVSingleTableSynthesizer - _fit              - INFO     - Successfully fitted synthesizer with data
# 2025-07-31 13:05:31,967 - PETsARD.SDVSingleTableSynthesizer - fit               - INFO     - Successfully fitting SDVSingleTableSynthesizer
# 2025-07-31 13:05:31,968 - PETsARD.Synthesizer   - fit               - INFO     - Fitting completed successfully in 4.8037 seconds
# 2025-07-31 13:05:31,968 - PETsARD.Synthesizer   - sample            - INFO     - Sampling 39073 rows using sdv-single_table-gaussiancopula
# 2025-07-31 13:05:31,969 - PETsARD.SDVSingleTableSynthesizer - sample            - INFO     - Sampling SDVSingleTableSynthesizer
# 2025-07-31 13:05:31,970 - PETsARD.SDVSingleTableSynthesizer - _sample           - INFO     - Sampling 39073 rows from synthesizer
# 2025-07-31 13:05:32,458 - PETsARD.SDVSingleTableSynthesizer - _sample           - INFO     - Successfully sampled 39073 rows
# 2025-07-31 13:05:32,459 - PETsARD.SDVSingleTableSynthesizer - _sample           - DEBUG    - Generated data shape: (39073, 15)
# 2025-07-31 13:05:32,459 - PETsARD.SDVSingleTableSynthesizer - sample            - INFO     - Successfully sampling SDVSingleTableSynthesizer
# 2025-07-31 13:05:32,459 - PETsARD.Synthesizer   - sample            - INFO     - Successfully sampled 39073 rows in 0.4909 seconds
# 2025-07-31 13:05:32,460 - PETsARD.Synthesizer   - sample            - DEBUG    - Sampled data shape: (39073, 15), dtypes: {dtype('int8'): 3, dtype('int32'): 2, CategoricalDtype(categories=['?', 'Federal-gov', 'Local-gov', 'Never-worked', 'Private',
#                   'Self-emp-inc', 'Self-emp-not-inc', 'State-gov',
#                   'Without-pay'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['10th', '11th', '12th', '1st-4th', '5th-6th', '7th-8th',
#                   '9th', 'Assoc-acdm', 'Assoc-voc', 'Bachelors', 'Doctorate',
#                   'HS-grad', 'Masters', 'Preschool', 'Prof-school',
#                   'Some-college'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Divorced', 'Married-AF-spouse', 'Married-civ-spouse',
#                   'Married-spouse-absent', 'Never-married', 'Separated',
#                   'Widowed'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['?', 'Adm-clerical', 'Armed-Forces', 'Craft-repair',
#                   'Exec-managerial', 'Farming-fishing', 'Handlers-cleaners',
#                   'Machine-op-inspct', 'Other-service', 'Priv-house-serv',
#                   'Prof-specialty', 'Protective-serv', 'Sales', 'Tech-support',
#                   'Transport-moving'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Husband', 'Not-in-family', 'Other-relative', 'Own-child',
#                   'Unmarried', 'Wife'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Amer-Indian-Eskimo', 'Asian-Pac-Islander', 'Black', 'Other',
#                   'White'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Female', 'Male'], ordered=False, categories_dtype=object): 1, dtype('int16'): 1, CategoricalDtype(categories=['?', 'Cambodia', 'Canada', 'China', 'Columbia', 'Cuba',
#                   'Dominican-Republic', 'Ecuador', 'El-Salvador', 'England',
#                   'France', 'Germany', 'Greece', 'Guatemala', 'Haiti',
#                   'Holand-Netherlands', 'Honduras', 'Hong', 'Hungary', 'India',
#                   'Iran', 'Ireland', 'Italy', 'Jamaica', 'Japan', 'Laos',
#                   'Mexico', 'Nicaragua', 'Outlying-US(Guam-USVI-etc)', 'Peru',
#                   'Philippines', 'Poland', 'Portugal', 'Puerto-Rico',
#                   'Scotland', 'South', 'Taiwan', 'Thailand', 'Trinadad&Tobago',
#                   'United-States', 'Vietnam', 'Yugoslavia'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['<=50K', '>50K'], ordered=False, categories_dtype=object): 1}
# 2025-07-31 13:05:32,462 - PETsARD.SynthesizerOp - _run              - DEBUG    - Train and sampling Synthesizing model completed
# 2025-07-31 13:05:32,462 - PETsARD.SynthesizerOp - run               - INFO     - TIMING_END|SynthesizerOp|run|1753938332.462681|5.302724838256836
# 2025-07-31 13:05:32,462 - PETsARD.Status        - _handle_timing_end - DEBUG    - 從 logging 結束計時: SynthesizerOp_default_run - 耗時: 0:00:05
# 2025-07-31 13:05:32,463 - PETsARD.SynthesizerOp - run               - INFO     - Completed SynthesizerOp execution (elapsed: 0:00:05)
# 2025-07-31 13:05:32,463 - PETsARD.Status        - _create_snapshot  - DEBUG    - 建立快照: snapshot_000004_20250731_130532 for Synthesizer[demo]
# 2025-07-31 13:05:32,463 - PETsARD.Status        - put               - INFO     - 狀態已更新: Synthesizer[demo] - 快照數量: 4
# 2025-07-31 13:05:32,463 - PETsARD.Executor      - run               - INFO     - Executing Postprocessor with demo
# 2025-07-31 13:05:32,464 - PETsARD.PostprocessorOp - run               - INFO     - TIMING_START|PostprocessorOp|run|1753938332.464491
# 2025-07-31 13:05:32,464 - PETsARD.Status        - _handle_timing_start - DEBUG    - 從 logging 開始計時: PostprocessorOp_default_run - timing_000005_20250731_130532
# 2025-07-31 13:05:32,464 - PETsARD.PostprocessorOp - run               - INFO     - Starting PostprocessorOp execution
# 2025-07-31 13:05:32,465 - PETsARD.PostprocessorOp - _run              - DEBUG    - Starting data postprocessing process
# 2025-07-31 13:05:32,465 - PETsARD.PostprocessorOp - _run              - DEBUG    - Processor configuration loading completed
# 2025-07-31 13:05:32,465 - PETsARD.Processor     - inverse_transform - INFO     - MediatorEncoder is created.
# 2025-07-31 13:05:32,465 - PETsARD.Processor     - inverse_transform - INFO     - MediatorScaler is created.
# 2025-07-31 13:05:32,465 - PETsARD.Processor     - inverse_transform - DEBUG    - Inverse sequence generation completed.
# 2025-07-31 13:05:32,466 - PETsARD.Processor     - inverse_transform - DEBUG    - mediator: MediatorScaler start inverse transforming.
# 2025-07-31 13:05:32,466 - PETsARD.Processor     - inverse_transform - DEBUG    - before transformation: data shape: (39073, 15)
# 2025-07-31 13:05:32,466 - PETsARD.Processor     - inverse_transform - DEBUG    - after transformation: data shape: (39073, 15)
# 2025-07-31 13:05:32,467 - PETsARD.Processor     - inverse_transform - INFO     - MediatorScaler transformation done.
# 2025-07-31 13:05:32,467 - PETsARD.Processor     - inverse_transform - INFO     - str inverse transformation done.
# 2025-07-31 13:05:32,467 - PETsARD.Processor     - inverse_transform - DEBUG    - mediator: MediatorEncoder start inverse transforming.
# 2025-07-31 13:05:32,467 - PETsARD.Processor     - inverse_transform - DEBUG    - before transformation: data shape: (39073, 15)
# 2025-07-31 13:05:32,467 - PETsARD.Processor     - inverse_transform - DEBUG    - after transformation: data shape: (39073, 15)
# 2025-07-31 13:05:32,468 - PETsARD.Processor     - inverse_transform - INFO     - MediatorEncoder transformation done.
# 2025-07-31 13:05:32,468 - PETsARD.Processor     - inverse_transform - INFO     - str inverse transformation done.
# 2025-07-31 13:05:32,468 - PETsARD.Processor     - inverse_transform - INFO     - str inverse transformation done.
# 2025-07-31 13:05:32,469 - PETsARD.PostprocessorOp - _run              - DEBUG    - Data postprocessing completed
# 2025-07-31 13:05:32,469 - PETsARD.PostprocessorOp - run               - INFO     - TIMING_END|PostprocessorOp|run|1753938332.469295|0.0047991275787353516
# 2025-07-31 13:05:32,469 - PETsARD.Status        - _handle_timing_end - DEBUG    - 從 logging 結束計時: PostprocessorOp_default_run - 耗時: N/A
# 2025-07-31 13:05:32,469 - PETsARD.PostprocessorOp - run               - INFO     - Completed PostprocessorOp execution (elapsed: 0:00:00)
# 2025-07-31 13:05:32,469 - PETsARD.Status        - _create_snapshot  - DEBUG    - 建立快照: snapshot_000005_20250731_130532 for Postprocessor[demo]
# 2025-07-31 13:05:32,470 - PETsARD.Status        - put               - INFO     - 狀態已更新: Postprocessor[demo] - 快照數量: 5
# 2025-07-31 13:05:32,470 - PETsARD.Executor      - run               - INFO     - Executing Evaluator with demo-diagnostic
# 2025-07-31 13:05:32,472 - PETsARD.EvaluatorOp   - run               - INFO     - TIMING_START|EvaluatorOp|run|1753938332.4721532
# 2025-07-31 13:05:32,472 - PETsARD.Status        - _handle_timing_start - DEBUG    - 從 logging 開始計時: EvaluatorOp_default_run - timing_000006_20250731_130532
# 2025-07-31 13:05:32,472 - PETsARD.EvaluatorOp   - run               - INFO     - Starting EvaluatorOp execution
# 2025-07-31 13:05:32,473 - PETsARD.EvaluatorOp   - _run              - DEBUG    - Starting data evaluating process
# 2025-07-31 13:05:32,473 - PETsARD.Evaluator     - create            - INFO     - Creating {self.__class__.__name__} instance
# 2025-07-31 13:05:32,473 - PETsARD.Evaluator     - create            - DEBUG    - Using Evaluator class: SDMetricsSingleTable
# 2025-07-31 13:05:32,473 - PETsARD.Evaluator     - create            - DEBUG    - Merged config keys: ['eval_method']
# 2025-07-31 13:05:32,474 - PETsARD.Evaluator     - create            - INFO     - Creating SDMetricsSingleTable instance
# 2025-07-31 13:05:32,474 - PETsARD.SDMetricsSingleTable - __init__          - DEBUG    - Initializing synthesizer with method: sdmetrics-diagnosticreport
# 2025-07-31 13:05:32,474 - PETsARD.SDMetricsSingleTable - __init__          - DEBUG    - Mapped method code: SDMetricsSingleTableMap.DIAGNOSTICREPORT
# 2025-07-31 13:05:32,476 - PETsARD.Evaluator     - create            - INFO     - Successfully created SDMetricsSingleTable instance
# 2025-07-31 13:05:32,477 - PETsARD.EvaluatorOp   - _run              - DEBUG    - Evaluation model initialization completed
# 2025-07-31 13:05:32,477 - PETsARD.Evaluator     - eval              - INFO     - Evaluating data with keys ['ori', 'syn', 'control'] using evaluation method: sdmetrics-diagnosticreport
# 2025-07-31 13:05:32,478 - PETsARD.EvaluatorInputConfig - __post_init__     - DEBUG    - Initializing EvaluatorInputDataConfig
# 2025-07-31 13:05:32,552 - PETsARD.SDMetricsSingleTable - eval              - DEBUG    - Merged config keys: ['ori', 'syn']
# 2025-07-31 13:05:32,553 - PETsARD.SDMetricsSingleTable - eval              - INFO     - Evaluating SDMetricsSingleTable
# 2025-07-31 13:05:32,553 - PETsARD.SDMetricsSingleTable - _eval             - INFO     - Evaluating with data
# 2025-07-31 13:05:32,553 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Initializing SDMetricsSingleTableConfig
# 2025-07-31 13:05:32,554 - PETsARD.SDMetricsSingleTableConfig - create_metadata   - DEBUG    - Creating SDV metadata
# 2025-07-31 13:05:32,575 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Initializing evaluator in _eval method
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 15/15 [00:00<00:00, 990.23it/s]|
# Data Validity Score: 100.0%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 745.26it/s]|
# Data Structure Score: 100.0%
# 2025-07-31 13:05:32,594 - PETsARD.SDMetricsSingleTable - _eval             - INFO     - Successfully evaluating from data
# 2025-07-31 13:05:32,594 - PETsARD.SDMetricsSingleTable - _extract_scores   - DEBUG    - Extract scores level from SDMetrics
# 2025-07-31 13:05:32,595 - PETsARD.SDMetricsSingleTable - _extract_scores   - DEBUG    - Extracting properties level from SDMetrics
# 2025-07-31 13:05:32,596 - PETsARD.SDMetricsSingleTable - _extract_scores   - DEBUG    - Extracting details level from SDMetrics
# 2025-07-31 13:05:32,597 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Extracted scores: ['score', 'properties', 'details']
# 2025-07-31 13:05:32,597 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Extracting global level as PETsARD format
# 2025-07-31 13:05:32,597 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Extracting columnwise level as PETsARD format
# 2025-07-31 13:05:32,598 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Extracting pairwise level as PETsARD format
# 2025-07-31 13:05:32,598 - PETsARD.SDMetricsSingleTable - _eval             - INFO     - Successfully extracting scores
# 2025-07-31 13:05:32,599 - PETsARD.SDMetricsSingleTable - eval              - INFO     - Successfully evaluating SDMetricsSingleTable
# 2025-07-31 13:05:32,599 - PETsARD.Evaluator     - eval              - INFO     - Evaluation completed successfully in 0.1217 seconds
# 2025-07-31 13:05:32,600 - PETsARD.Evaluator     - eval              - DEBUG    - Evaluation report summary: Data keys: ['ori', 'syn', 'control'], Column count by type per dataframe: {'ori': {dtype('int8'): 3, dtype('int32'): 2, CategoricalDtype(categories=['?', 'Federal-gov', 'Local-gov', 'Never-worked', 'Private',
#                   'Self-emp-inc', 'Self-emp-not-inc', 'State-gov',
#                   'Without-pay'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['10th', '11th', '12th', '1st-4th', '5th-6th', '7th-8th',
#                   '9th', 'Assoc-acdm', 'Assoc-voc', 'Bachelors', 'Doctorate',
#                   'HS-grad', 'Masters', 'Preschool', 'Prof-school',
#                   'Some-college'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Divorced', 'Married-AF-spouse', 'Married-civ-spouse',
#                   'Married-spouse-absent', 'Never-married', 'Separated',
#                   'Widowed'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['?', 'Adm-clerical', 'Armed-Forces', 'Craft-repair',
#                   'Exec-managerial', 'Farming-fishing', 'Handlers-cleaners',
#                   'Machine-op-inspct', 'Other-service', 'Priv-house-serv',
#                   'Prof-specialty', 'Protective-serv', 'Sales', 'Tech-support',
#                   'Transport-moving'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Husband', 'Not-in-family', 'Other-relative', 'Own-child',
#                   'Unmarried', 'Wife'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Amer-Indian-Eskimo', 'Asian-Pac-Islander', 'Black', 'Other',
#                   'White'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Female', 'Male'], ordered=False, categories_dtype=object): 1, dtype('int16'): 1, CategoricalDtype(categories=['?', 'Cambodia', 'Canada', 'China', 'Columbia', 'Cuba',
#                   'Dominican-Republic', 'Ecuador', 'El-Salvador', 'England',
#                   'France', 'Germany', 'Greece', 'Guatemala', 'Haiti',
#                   'Holand-Netherlands', 'Honduras', 'Hong', 'Hungary', 'India',
#                   'Iran', 'Ireland', 'Italy', 'Jamaica', 'Japan', 'Laos',
#                   'Mexico', 'Nicaragua', 'Outlying-US(Guam-USVI-etc)', 'Peru',
#                   'Philippines', 'Poland', 'Portugal', 'Puerto-Rico',
#                   'Scotland', 'South', 'Taiwan', 'Thailand', 'Trinadad&Tobago',
#                   'United-States', 'Vietnam', 'Yugoslavia'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['<=50K', '>50K'], ordered=False, categories_dtype=object): 1}, 'syn': {dtype('int8'): 3, dtype('int32'): 2, CategoricalDtype(categories=['?', 'Federal-gov', 'Local-gov', 'Never-worked', 'Private',
#                   'Self-emp-inc', 'Self-emp-not-inc', 'State-gov',
#                   'Without-pay'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['10th', '11th', '12th', '1st-4th', '5th-6th', '7th-8th',
#                   '9th', 'Assoc-acdm', 'Assoc-voc', 'Bachelors', 'Doctorate',
#                   'HS-grad', 'Masters', 'Preschool', 'Prof-school',
#                   'Some-college'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Divorced', 'Married-AF-spouse', 'Married-civ-spouse',
#                   'Married-spouse-absent', 'Never-married', 'Separated',
#                   'Widowed'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['?', 'Adm-clerical', 'Armed-Forces', 'Craft-repair',
#                   'Exec-managerial', 'Farming-fishing', 'Handlers-cleaners',
#                   'Machine-op-inspct', 'Other-service', 'Priv-house-serv',
#                   'Prof-specialty', 'Protective-serv', 'Sales', 'Tech-support',
#                   'Transport-moving'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Husband', 'Not-in-family', 'Other-relative', 'Own-child',
#                   'Unmarried', 'Wife'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Amer-Indian-Eskimo', 'Asian-Pac-Islander', 'Black', 'Other',
#                   'White'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Female', 'Male'], ordered=False, categories_dtype=object): 1, dtype('int16'): 1, CategoricalDtype(categories=['?', 'Cambodia', 'Canada', 'China', 'Columbia', 'Cuba',
#                   'Dominican-Republic', 'Ecuador', 'El-Salvador', 'England',
#                   'France', 'Germany', 'Greece', 'Guatemala', 'Haiti',
#                   'Holand-Netherlands', 'Honduras', 'Hong', 'Hungary', 'India',
#                   'Iran', 'Ireland', 'Italy', 'Jamaica', 'Japan', 'Laos',
#                   'Mexico', 'Nicaragua', 'Outlying-US(Guam-USVI-etc)', 'Peru',
#                   'Philippines', 'Poland', 'Portugal', 'Puerto-Rico',
#                   'Scotland', 'South', 'Taiwan', 'Thailand', 'Trinadad&Tobago',
#                   'United-States', 'Vietnam', 'Yugoslavia'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['<=50K', '>50K'], ordered=False, categories_dtype=object): 1}, 'control': {dtype('int8'): 3, dtype('int32'): 2, CategoricalDtype(categories=['?', 'Federal-gov', 'Local-gov', 'Never-worked', 'Private',
#                   'Self-emp-inc', 'Self-emp-not-inc', 'State-gov',
#                   'Without-pay'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['10th', '11th', '12th', '1st-4th', '5th-6th', '7th-8th',
#                   '9th', 'Assoc-acdm', 'Assoc-voc', 'Bachelors', 'Doctorate',
#                   'HS-grad', 'Masters', 'Preschool', 'Prof-school',
#                   'Some-college'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Divorced', 'Married-AF-spouse', 'Married-civ-spouse',
#                   'Married-spouse-absent', 'Never-married', 'Separated',
#                   'Widowed'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['?', 'Adm-clerical', 'Armed-Forces', 'Craft-repair',
#                   'Exec-managerial', 'Farming-fishing', 'Handlers-cleaners',
#                   'Machine-op-inspct', 'Other-service', 'Priv-house-serv',
#                   'Prof-specialty', 'Protective-serv', 'Sales', 'Tech-support',
#                   'Transport-moving'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Husband', 'Not-in-family', 'Other-relative', 'Own-child',
#                   'Unmarried', 'Wife'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Amer-Indian-Eskimo', 'Asian-Pac-Islander', 'Black', 'Other',
#                   'White'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Female', 'Male'], ordered=False, categories_dtype=object): 1, dtype('int16'): 1, CategoricalDtype(categories=['?', 'Cambodia', 'Canada', 'China', 'Columbia', 'Cuba',
#                   'Dominican-Republic', 'Ecuador', 'El-Salvador', 'England',
#                   'France', 'Germany', 'Greece', 'Guatemala', 'Haiti',
#                   'Holand-Netherlands', 'Honduras', 'Hong', 'Hungary', 'India',
#                   'Iran', 'Ireland', 'Italy', 'Jamaica', 'Japan', 'Laos',
#                   'Mexico', 'Nicaragua', 'Outlying-US(Guam-USVI-etc)', 'Peru',
#                   'Philippines', 'Poland', 'Portugal', 'Puerto-Rico',
#                   'Scotland', 'South', 'Taiwan', 'Thailand', 'Trinadad&Tobago',
#                   'United-States', 'Vietnam', 'Yugoslavia'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['<=50K', '>50K'], ordered=False, categories_dtype=object): 1}}, Columns by key: {'ori': ['age', 'workclass', 'fnlwgt', 'education', 'educational-num', 'marital-status', 'occupation', 'relationship', 'race', 'gender', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country', 'income'], 'syn': ['age', 'workclass', 'fnlwgt', 'education', 'educational-num', 'marital-status', 'occupation', 'relationship', 'race', 'gender', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country', 'income'], 'control': ['age', 'workclass', 'fnlwgt', 'education', 'educational-num', 'marital-status', 'occupation', 'relationship', 'race', 'gender', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country', 'income']}
# 2025-07-31 13:05:32,600 - PETsARD.EvaluatorOp   - _run              - DEBUG    - Data evaluating completed
# 2025-07-31 13:05:32,601 - PETsARD.EvaluatorOp   - run               - INFO     - TIMING_END|EvaluatorOp|run|1753938332.6010408|0.12888383865356445
# 2025-07-31 13:05:32,601 - PETsARD.Status        - _handle_timing_end - DEBUG    - 從 logging 結束計時: EvaluatorOp_default_run - 耗時: 0:00:00
# 2025-07-31 13:05:32,601 - PETsARD.EvaluatorOp   - run               - INFO     - Completed EvaluatorOp execution (elapsed: 0:00:00)
# 2025-07-31 13:05:32,601 - PETsARD.Status        - _create_snapshot  - DEBUG    - 建立快照: snapshot_000006_20250731_130532 for Evaluator[demo-diagnostic]
# 2025-07-31 13:05:32,601 - PETsARD.Status        - put               - INFO     - 狀態已更新: Evaluator[demo-diagnostic] - 快照數量: 6
# 2025-07-31 13:05:32,602 - PETsARD.Executor      - run               - INFO     - Executing Reporter with output
# 2025-07-31 13:05:32,606 - PETsARD.ReporterOp    - run               - INFO     - TIMING_START|ReporterOp|run|1753938332.60689
# 2025-07-31 13:05:32,607 - PETsARD.Status        - _handle_timing_start - DEBUG    - 從 logging 開始計時: ReporterOp_default_run - timing_000007_20250731_130532
# 2025-07-31 13:05:32,607 - PETsARD.ReporterOp    - run               - INFO     - Starting ReporterOp execution
# 2025-07-31 13:05:32,607 - PETsARD.ReporterOp    - _run              - DEBUG    - Starting data reporting process
# 2025-07-31 13:05:32,608 - PETsARD.petsard.reporter.reporter - _verify_create_input - INFO     - Removing 'exist_report': All entries were invalid
# 2025-07-31 13:05:32,608 - PETsARD.petsard.reporter.reporter - _verify_create_input - INFO     - Removing key timing_data: Index must have even number of elements
# 2025-07-31 13:05:32,608 - PETsARD.petsard.reporter.reporter - _verify_create_input - INFO     - Removed 2 invalid entries from input data
# 2025-07-31 13:05:32,609 - PETsARD.ReporterOp    - _run              - DEBUG    - Reporting configuration initialization completed
# 2025-07-31 13:05:32,695 - PETsARD.ReporterOp    - _run              - DEBUG    - Data reporting completed
# 2025-07-31 13:05:32,696 - PETsARD.ReporterOp    - run               - INFO     - TIMING_END|ReporterOp|run|1753938332.696149|0.08925318717956543
# 2025-07-31 13:05:32,696 - PETsARD.Status        - _handle_timing_end - DEBUG    - 從 logging 結束計時: ReporterOp_default_run - 耗時: 0:00:00
# 2025-07-31 13:05:32,696 - PETsARD.ReporterOp    - run               - INFO     - Completed ReporterOp execution (elapsed: 0:00:00)
# 2025-07-31 13:05:32,697 - PETsARD.Status        - _create_snapshot  - DEBUG    - 建立快照: snapshot_000007_20250731_130532 for Reporter[output]
# 2025-07-31 13:05:32,697 - PETsARD.Status        - put               - INFO     - 狀態已更新: Reporter[output] - 快照數量: 7
# 2025-07-31 13:05:32,697 - PETsARD.Executor      - _set_result       - DEBUG    - Collecting final results for Reporter
# 2025-07-31 13:05:32,698 - PETsARD.Executor      - run               - INFO     - Executing Reporter with save_report_global
# 2025-07-31 13:05:32,701 - PETsARD.ReporterOp    - run               - INFO     - TIMING_START|ReporterOp|run|1753938332.701034
# 2025-07-31 13:05:32,701 - PETsARD.Status        - _handle_timing_start - DEBUG    - 從 logging 開始計時: ReporterOp_output_run - timing_000008_20250731_130532
# 2025-07-31 13:05:32,701 - PETsARD.ReporterOp    - run               - INFO     - Starting ReporterOp execution
# 2025-07-31 13:05:32,701 - PETsARD.ReporterOp    - _run              - DEBUG    - Starting data reporting process
# 2025-07-31 13:05:32,702 - PETsARD.petsard.reporter.reporter - _verify_create_input - INFO     - Removing key timing_data: Index must have even number of elements
# 2025-07-31 13:05:32,702 - PETsARD.petsard.reporter.reporter - _verify_create_input - INFO     - Removed 1 invalid entries from input data
# 2025-07-31 13:05:32,703 - PETsARD.ReporterOp    - _run              - DEBUG    - Reporting configuration initialization completed
# 2025-07-31 13:05:32,704 - PETsARD.ReporterOp    - _run              - DEBUG    - Data reporting completed
# 2025-07-31 13:05:32,704 - PETsARD.ReporterOp    - run               - INFO     - TIMING_END|ReporterOp|run|1753938332.704768|0.003728151321411133
# 2025-07-31 13:05:32,705 - PETsARD.Status        - _handle_timing_end - DEBUG    - 從 logging 結束計時: ReporterOp_output_run - 耗時: N/A
# 2025-07-31 13:05:32,705 - PETsARD.ReporterOp    - run               - INFO     - Completed ReporterOp execution (elapsed: 0:00:00)
# 2025-07-31 13:05:32,705 - PETsARD.Status        - _create_snapshot  - DEBUG    - 建立快照: snapshot_000008_20250731_130532 for Reporter[save_report_global]
# 2025-07-31 13:05:32,706 - PETsARD.Status        - put               - INFO     - 狀態已更新: Reporter[save_report_global] - 快照數量: 8
# 2025-07-31 13:05:32,707 - PETsARD.Executor      - _set_result       - DEBUG    - Collecting final results for Reporter
# 2025-07-31 13:05:32,707 - PETsARD.Executor      - run               - INFO     - Executing Evaluator with demo-quality
# 2025-07-31 13:05:32,708 - PETsARD.EvaluatorOp   - run               - INFO     - TIMING_START|EvaluatorOp|run|1753938332.708447
# 2025-07-31 13:05:32,708 - PETsARD.Status        - _handle_timing_start - DEBUG    - 從 logging 開始計時: EvaluatorOp_demo-diagnostic_run - timing_000009_20250731_130532
# 2025-07-31 13:05:32,709 - PETsARD.EvaluatorOp   - run               - INFO     - Starting EvaluatorOp execution
# 2025-07-31 13:05:32,709 - PETsARD.EvaluatorOp   - _run              - DEBUG    - Starting data evaluating process
# 2025-07-31 13:05:32,709 - PETsARD.Evaluator     - create            - INFO     - Creating {self.__class__.__name__} instance
# 2025-07-31 13:05:32,709 - PETsARD.Evaluator     - create            - DEBUG    - Using Evaluator class: SDMetricsSingleTable
# 2025-07-31 13:05:32,709 - PETsARD.Evaluator     - create            - DEBUG    - Merged config keys: ['eval_method']
# 2025-07-31 13:05:32,709 - PETsARD.Evaluator     - create            - INFO     - Creating SDMetricsSingleTable instance
# ...
# 2025-07-31 13:05:33,341 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Warning during _eval: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# 2025-07-31 13:05:33,341 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Warning during _eval: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# 2025-07-31 13:05:33,342 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Warning during _eval: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
# 2025-07-31 13:05:33,342 - PETsARD.SDMetricsSingleTable - _eval             - INFO     - Successfully evaluating from data
# 2025-07-31 13:05:33,343 - PETsARD.SDMetricsSingleTable - _extract_scores   - DEBUG    - Extract scores level from SDMetrics
# 2025-07-31 13:05:33,344 - PETsARD.SDMetricsSingleTable - _extract_scores   - DEBUG    - Extracting properties level from SDMetrics
# 2025-07-31 13:05:33,344 - PETsARD.SDMetricsSingleTable - _extract_scores   - DEBUG    - Extracting details level from SDMetrics
# 2025-07-31 13:05:33,345 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Extracted scores: ['score', 'properties', 'details']
# 2025-07-31 13:05:33,345 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Extracting global level as PETsARD format
# 2025-07-31 13:05:33,345 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Extracting columnwise level as PETsARD format
# 2025-07-31 13:05:33,346 - PETsARD.SDMetricsSingleTable - _eval             - DEBUG    - Extracting pairwise level as PETsARD format
# 2025-07-31 13:05:33,347 - PETsARD.SDMetricsSingleTable - _eval             - INFO     - Successfully extracting scores
# 2025-07-31 13:05:33,347 - PETsARD.SDMetricsSingleTable - eval              - INFO     - Successfully evaluating SDMetricsSingleTable
# 2025-07-31 13:05:33,347 - PETsARD.Evaluator     - eval              - INFO     - Evaluation completed successfully in 0.6357 seconds
# 2025-07-31 13:05:33,349 - PETsARD.Evaluator     - eval              - DEBUG    - Evaluation report summary: Data keys: ['ori', 'syn', 'control'], Column count by type per dataframe: {'ori': {dtype('int8'): 3, dtype('int32'): 2, CategoricalDtype(categories=['?', 'Federal-gov', 'Local-gov', 'Never-worked', 'Private',
#                   'Self-emp-inc', 'Self-emp-not-inc', 'State-gov',
#                   'Without-pay'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['10th', '11th', '12th', '1st-4th', '5th-6th', '7th-8th',
#                   '9th', 'Assoc-acdm', 'Assoc-voc', 'Bachelors', 'Doctorate',
#                   'HS-grad', 'Masters', 'Preschool', 'Prof-school',
#                   'Some-college'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Divorced', 'Married-AF-spouse', 'Married-civ-spouse',
#                   'Married-spouse-absent', 'Never-married', 'Separated',
#                   'Widowed'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['?', 'Adm-clerical', 'Armed-Forces', 'Craft-repair',
#                   'Exec-managerial', 'Farming-fishing', 'Handlers-cleaners',
#                   'Machine-op-inspct', 'Other-service', 'Priv-house-serv',
#                   'Prof-specialty', 'Protective-serv', 'Sales', 'Tech-support',
#                   'Transport-moving'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Husband', 'Not-in-family', 'Other-relative', 'Own-child',
#                   'Unmarried', 'Wife'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Amer-Indian-Eskimo', 'Asian-Pac-Islander', 'Black', 'Other',
#                   'White'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Female', 'Male'], ordered=False, categories_dtype=object): 1, dtype('int16'): 1, CategoricalDtype(categories=['?', 'Cambodia', 'Canada', 'China', 'Columbia', 'Cuba',
#                   'Dominican-Republic', 'Ecuador', 'El-Salvador', 'England',
#                   'France', 'Germany', 'Greece', 'Guatemala', 'Haiti',
#                   'Holand-Netherlands', 'Honduras', 'Hong', 'Hungary', 'India',
#                   'Iran', 'Ireland', 'Italy', 'Jamaica', 'Japan', 'Laos',
#                   'Mexico', 'Nicaragua', 'Outlying-US(Guam-USVI-etc)', 'Peru',
#                   'Philippines', 'Poland', 'Portugal', 'Puerto-Rico',
#                   'Scotland', 'South', 'Taiwan', 'Thailand', 'Trinadad&Tobago',
#                   'United-States', 'Vietnam', 'Yugoslavia'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['<=50K', '>50K'], ordered=False, categories_dtype=object): 1}, 'syn': {dtype('int8'): 3, dtype('int32'): 2, CategoricalDtype(categories=['?', 'Federal-gov', 'Local-gov', 'Never-worked', 'Private',
#                   'Self-emp-inc', 'Self-emp-not-inc', 'State-gov',
#                   'Without-pay'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['10th', '11th', '12th', '1st-4th', '5th-6th', '7th-8th',
#                   '9th', 'Assoc-acdm', 'Assoc-voc', 'Bachelors', 'Doctorate',
#                   'HS-grad', 'Masters', 'Preschool', 'Prof-school',
#                   'Some-college'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Divorced', 'Married-AF-spouse', 'Married-civ-spouse',
#                   'Married-spouse-absent', 'Never-married', 'Separated',
#                   'Widowed'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['?', 'Adm-clerical', 'Armed-Forces', 'Craft-repair',
#                   'Exec-managerial', 'Farming-fishing', 'Handlers-cleaners',
#                   'Machine-op-inspct', 'Other-service', 'Priv-house-serv',
#                   'Prof-specialty', 'Protective-serv', 'Sales', 'Tech-support',
#                   'Transport-moving'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Husband', 'Not-in-family', 'Other-relative', 'Own-child',
#                   'Unmarried', 'Wife'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Amer-Indian-Eskimo', 'Asian-Pac-Islander', 'Black', 'Other',
#                   'White'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Female', 'Male'], ordered=False, categories_dtype=object): 1, dtype('int16'): 1, CategoricalDtype(categories=['?', 'Cambodia', 'Canada', 'China', 'Columbia', 'Cuba',
#                   'Dominican-Republic', 'Ecuador', 'El-Salvador', 'England',
#                   'France', 'Germany', 'Greece', 'Guatemala', 'Haiti',
#                   'Holand-Netherlands', 'Honduras', 'Hong', 'Hungary', 'India',
#                   'Iran', 'Ireland', 'Italy', 'Jamaica', 'Japan', 'Laos',
#                   'Mexico', 'Nicaragua', 'Outlying-US(Guam-USVI-etc)', 'Peru',
#                   'Philippines', 'Poland', 'Portugal', 'Puerto-Rico',
#                   'Scotland', 'South', 'Taiwan', 'Thailand', 'Trinadad&Tobago',
#                   'United-States', 'Vietnam', 'Yugoslavia'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['<=50K', '>50K'], ordered=False, categories_dtype=object): 1}, 'control': {dtype('int8'): 3, dtype('int32'): 2, CategoricalDtype(categories=['?', 'Federal-gov', 'Local-gov', 'Never-worked', 'Private',
#                   'Self-emp-inc', 'Self-emp-not-inc', 'State-gov',
#                   'Without-pay'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['10th', '11th', '12th', '1st-4th', '5th-6th', '7th-8th',
#                   '9th', 'Assoc-acdm', 'Assoc-voc', 'Bachelors', 'Doctorate',
#                   'HS-grad', 'Masters', 'Preschool', 'Prof-school',
#                   'Some-college'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Divorced', 'Married-AF-spouse', 'Married-civ-spouse',
#                   'Married-spouse-absent', 'Never-married', 'Separated',
#                   'Widowed'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['?', 'Adm-clerical', 'Armed-Forces', 'Craft-repair',
#                   'Exec-managerial', 'Farming-fishing', 'Handlers-cleaners',
#                   'Machine-op-inspct', 'Other-service', 'Priv-house-serv',
#                   'Prof-specialty', 'Protective-serv', 'Sales', 'Tech-support',
#                   'Transport-moving'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Husband', 'Not-in-family', 'Other-relative', 'Own-child',
#                   'Unmarried', 'Wife'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Amer-Indian-Eskimo', 'Asian-Pac-Islander', 'Black', 'Other',
#                   'White'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['Female', 'Male'], ordered=False, categories_dtype=object): 1, dtype('int16'): 1, CategoricalDtype(categories=['?', 'Cambodia', 'Canada', 'China', 'Columbia', 'Cuba',
#                   'Dominican-Republic', 'Ecuador', 'El-Salvador', 'England',
#                   'France', 'Germany', 'Greece', 'Guatemala', 'Haiti',
#                   'Holand-Netherlands', 'Honduras', 'Hong', 'Hungary', 'India',
#                   'Iran', 'Ireland', 'Italy', 'Jamaica', 'Japan', 'Laos',
#                   'Mexico', 'Nicaragua', 'Outlying-US(Guam-USVI-etc)', 'Peru',
#                   'Philippines', 'Poland', 'Portugal', 'Puerto-Rico',
#                   'Scotland', 'South', 'Taiwan', 'Thailand', 'Trinadad&Tobago',
#                   'United-States', 'Vietnam', 'Yugoslavia'],
# , ordered=False, categories_dtype=object): 1, CategoricalDtype(categories=['<=50K', '>50K'], ordered=False, categories_dtype=object): 1}}, Columns by key: {'ori': ['age', 'workclass', 'fnlwgt', 'education', 'educational-num', 'marital-status', 'occupation', 'relationship', 'race', 'gender', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country', 'income'], 'syn': ['age', 'workclass', 'fnlwgt', 'education', 'educational-num', 'marital-status', 'occupation', 'relationship', 'race', 'gender', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country', 'income'], 'control': ['age', 'workclass', 'fnlwgt', 'education', 'educational-num', 'marital-status', 'occupation', 'relationship', 'race', 'gender', 'capital-gain', 'capital-loss', 'hours-per-week', 'native-country', 'income']}
# 2025-07-31 13:05:33,349 - PETsARD.EvaluatorOp   - _run              - DEBUG    - Data evaluating completed
# 2025-07-31 13:05:33,349 - PETsARD.EvaluatorOp   - run               - INFO     - TIMING_END|EvaluatorOp|run|1753938333.349764|0.6413130760192871
# 2025-07-31 13:05:33,350 - PETsARD.Status        - _handle_timing_end - DEBUG    - 從 logging 結束計時: EvaluatorOp_demo-diagnostic_run - 耗時: 0:00:01
# 2025-07-31 13:05:33,350 - PETsARD.EvaluatorOp   - run               - INFO     - Completed EvaluatorOp execution (elapsed: 0:00:01)
# 2025-07-31 13:05:33,351 - PETsARD.Status        - _create_snapshot  - DEBUG    - 建立快照: snapshot_000009_20250731_130533 for Evaluator[demo-quality]
# 2025-07-31 13:05:33,351 - PETsARD.Status        - put               - INFO     - 狀態已更新: Evaluator[demo-quality] - 快照數量: 9
# 2025-07-31 13:05:33,352 - PETsARD.Executor      - run               - INFO     - Executing Reporter with output
# 2025-07-31 13:05:33,356 - PETsARD.ReporterOp    - run               - INFO     - TIMING_START|ReporterOp|run|1753938333.3564281
# 2025-07-31 13:05:33,356 - PETsARD.Status        - _handle_timing_start - DEBUG    - 從 logging 開始計時: ReporterOp_save_report_global_run - timing_000010_20250731_130533
# 2025-07-31 13:05:33,357 - PETsARD.ReporterOp    - run               - INFO     - Starting ReporterOp execution
# 2025-07-31 13:05:33,357 - PETsARD.ReporterOp    - _run              - DEBUG    - Starting data reporting process
# 2025-07-31 13:05:33,357 - PETsARD.petsard.reporter.reporter - _verify_create_input - INFO     - Removing key timing_data: Index must have even number of elements
# 2025-07-31 13:05:33,357 - PETsARD.petsard.reporter.reporter - _verify_create_input - INFO     - Removed 1 invalid entries from input data
# 2025-07-31 13:05:33,358 - PETsARD.ReporterOp    - _run              - DEBUG    - Reporting configuration initialization completed
# Now is petsard_Loader[log-data]_Splitter[demo_[1-1]]_Preprocessor[demo]_Synthesizer[demo] save to csv...
# 2025-07-31 13:05:33,444 - PETsARD.ReporterOp    - _run              - DEBUG    - Data reporting completed
# 2025-07-31 13:05:33,444 - PETsARD.ReporterOp    - run               - INFO     - TIMING_END|ReporterOp|run|1753938333.444727|0.08829379081726074
# 2025-07-31 13:05:33,444 - PETsARD.Status        - _handle_timing_end - DEBUG    - 從 logging 結束計時: ReporterOp_save_report_global_run - 耗時: 0:00:00
# 2025-07-31 13:05:33,445 - PETsARD.ReporterOp    - run               - INFO     - Completed ReporterOp execution (elapsed: 0:00:00)
# 2025-07-31 13:05:33,445 - PETsARD.Status        - _create_snapshot  - DEBUG    - 建立快照: snapshot_000010_20250731_130533 for Reporter[output]
# 2025-07-31 13:05:33,446 - PETsARD.Status        - put               - INFO     - 狀態已更新: Reporter[output] - 快照數量: 10
# 2025-07-31 13:05:33,446 - PETsARD.Executor      - _set_result       - DEBUG    - Collecting final results for Reporter
# 2025-07-31 13:05:33,446 - PETsARD.Executor      - run               - INFO     - Executing Reporter with save_report_global
# 2025-07-31 13:05:33,449 - PETsARD.ReporterOp    - run               - INFO     - TIMING_START|ReporterOp|run|1753938333.4493492
# 2025-07-31 13:05:33,449 - PETsARD.Status        - _handle_timing_start - DEBUG    - 從 logging 開始計時: ReporterOp_output_run - timing_000011_20250731_130533
# 2025-07-31 13:05:33,449 - PETsARD.ReporterOp    - run               - INFO     - Starting ReporterOp execution
# 2025-07-31 13:05:33,450 - PETsARD.ReporterOp    - _run              - DEBUG    - Starting data reporting process
# 2025-07-31 13:05:33,450 - PETsARD.petsard.reporter.reporter - _verify_create_input - INFO     - Removing key timing_data: Index must have even number of elements
# 2025-07-31 13:05:33,450 - PETsARD.petsard.reporter.reporter - _verify_create_input - INFO     - Removed 1 invalid entries from input data
# 2025-07-31 13:05:33,452 - PETsARD.ReporterOp    - _run              - DEBUG    - Reporting configuration initialization completed
# 2025-07-31 13:05:33,453 - PETsARD.ReporterOp    - _run              - DEBUG    - Data reporting completed
# 2025-07-31 13:05:33,453 - PETsARD.ReporterOp    - run               - INFO     - TIMING_END|ReporterOp|run|1753938333.453913|0.0045588016510009766
# 2025-07-31 13:05:33,454 - PETsARD.Status        - _handle_timing_end - DEBUG    - 從 logging 結束計時: ReporterOp_output_run - 耗時: N/A
# 2025-07-31 13:05:33,454 - PETsARD.ReporterOp    - run               - INFO     - Completed ReporterOp execution (elapsed: 0:00:00)
# 2025-07-31 13:05:33,454 - PETsARD.Status        - _create_snapshot  - DEBUG    - 建立快照: snapshot_000011_20250731_130533 for Reporter[save_report_global]
# 2025-07-31 13:05:33,454 - PETsARD.Status        - put               - INFO     - 狀態已更新: Reporter[save_report_global] - 快照數量: 11
# 2025-07-31 13:05:33,455 - PETsARD.Executor      - _set_result       - DEBUG    - Collecting final results for Reporter
# 2025-07-31 13:05:33,455 - PETsARD.Executor      - run               - INFO     - Completed PETsARD execution workflow (elapsed: 0:00:07)
# Now is petsard[Report]_[global] save to csv...
