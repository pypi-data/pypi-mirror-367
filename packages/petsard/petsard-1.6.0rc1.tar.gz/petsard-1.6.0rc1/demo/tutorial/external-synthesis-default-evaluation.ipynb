# %% [markdown]
# # Environment setting / 環境設定
# External Synthesis with Default Evaluation / 外部合成與預設評測

# %%
import os
import sys
from pathlib import Path

# 自動載入 utils / Auto-load utils
if "COLAB_GPU" in os.environ:
    url = "https://raw.githubusercontent.com/nics-tw/petsard/main/demo/utils.py"
    exec(open(url).read())
else:
    # 靜默搜尋 utils.py / Silent search for utils.py
    current = Path.cwd()
    for _ in range(5):
        if (current / "utils.py").exists():
            sys.path.insert(0, str(current))
            break
        current = current.parent

    # 匯入 utils 模組 / Import utils module
    from utils import quick_setup

# 快速設定 / Quick setup
is_colab, branch, yaml_path = quick_setup(
    yaml_file="external-synthesis-default-evaluation.yaml",
    benchmark_data=[
        "adult-income_ori",
        "adult-income_control",
        "adult-income_syn",
    ],
    branch="main",  # 可選，預設為 "main"
)

from petsard import Executor
# Out:
# 🚀 PETsARD v1.6.0rc1
# 📅 2025-08-05 15:56:36 UTC+8
# 📁 Subfolder: tutorial
# 📄 YAML path: petsard/demo/tutorial/external-synthesis-default-evaluation.yaml
# ⚙️ Configuration content:
# ---
# Splitter:
#   custom:
#     method: 'custom_data'
#     filepath:
#       ori: 'benchmark/adult-income_ori.csv'
#       control: 'benchmark/adult-income_control.csv'
# Synthesizer:
#   custom:
#     method: 'custom_data'
#     filepath: 'benchmark/adult-income_syn.csv'
# Evaluator:
#   demo-diagnostic:
#     method: 'sdmetrics-diagnosticreport'
#   demo-quality:
#     method: 'sdmetrics-qualityreport'
#   demo-singlingout:
#     method: 'anonymeter-singlingout'
#   demo-linkability:
#     method: 'anonymeter-linkability'
#     aux_cols:
#       -
#         - 'age'
#         - 'marital-status'
#         - 'relationship'
#         - 'gender'
#       -
#         - 'workclass'
#         - 'educational-num'
#         - 'occupation'
#         - 'income'
#   demo-inference:
#     method: 'anonymeter-inference'
#     secret: 'income'
#   demo-classification:
#     method: 'mlutility-classification'
#     target: 'income'
# Reporter:
#   rpt:
#     method: 'save_report'
#     granularity:
#       - 'global'
#       - 'columnwise'
#       - 'pairwise'
#       - 'details'
# ...

# %% [markdown]
# # Execution and Result / 執行與結果

# %%
exec_case = Executor(config=yaml_path)
exec_case.run()
# Out:
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 15/15 [00:00<00:00, 206.99it/s]|
# Data Validity Score: 100.0%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 318.09it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 100.0%
#
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 15/15 [00:00<00:00, 100.53it/s]|
# Column Shapes Score: 95.26%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 105/105 [00:00<00:00, 147.95it/s]|
# Column Pair Trends Score: 61.56%
#
# Overall Score (Average): 78.41%
# Found 1652 failed queries out of 2000. Check DEBUG messages for more details.
# Reached maximum number of attempts 500000 when generating singling out queries. Returning 160 instead of the requested 2000.To avoid this, increase the number of attempts or set it to ``None`` to disable The limitation entirely.
# Attack `multivariate` could generate only 160 singling out queries out of the requested 2000. This can probably lead to an underestimate of the singling out risk.
# /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.11/site-packages/anonymeter/stats/confidence.py:218: UserWarning: Attack is as good or worse as baseline model. Estimated rates: attack = 0.0009585236406264672, baseline = 0.0009585236406264672. Analysis results cannot be trusted.
#   self._sanity_check()

# %%
exec_case.get_result()[
    "Splitter[custom_[1-1]]_Synthesizer[custom]_Evaluator[demo-quality]_Reporter[rpt]"
]["[global]"]
# Out:
#                                       full_expt_name      Splitter  \
# 0  Splitter[custom_[1-1]]_Synthesizer[custom]_Eva...  custom_[1-1]
#
#   Synthesizer Evaluator  demo-diagnostic_Score  demo-diagnostic_Data Validity  \
# 0      custom  [global]                    1.0                            1.0
#
#    demo-diagnostic_Data Structure  demo-quality_Score  \
# 0                             1.0                0.78
#
#    demo-quality_Column Shapes  demo-quality_Column Pair Trends
# 0                        0.95                             0.62

# %%
exec_case.get_result()[
    "Splitter[custom_[1-1]]_Synthesizer[custom]_Evaluator[demo-quality]_Reporter[rpt]"
]["[columnwise]"]
# Out:
#                                        full_expt_name      Splitter  \
# 0   Splitter[custom_[1-1]]_Synthesizer[custom]_Eva...  custom_[1-1]
# 1   Splitter[custom_[1-1]]_Synthesizer[custom]_Eva...  custom_[1-1]
# 2   Splitter[custom_[1-1]]_Synthesizer[custom]_Eva...  custom_[1-1]
# 3   Splitter[custom_[1-1]]_Synthesizer[custom]_Eva...  custom_[1-1]
# 4   Splitter[custom_[1-1]]_Synthesizer[custom]_Eva...  custom_[1-1]
# 5   Splitter[custom_[1-1]]_Synthesizer[custom]_Eva...  custom_[1-1]
# 6   Splitter[custom_[1-1]]_Synthesizer[custom]_Eva...  custom_[1-1]
# 7   Splitter[custom_[1-1]]_Synthesizer[custom]_Eva...  custom_[1-1]
# 8   Splitter[custom_[1-1]]_Synthesizer[custom]_Eva...  custom_[1-1]
# 9   Splitter[custom_[1-1]]_Synthesizer[custom]_Eva...  custom_[1-1]
# 10  Splitter[custom_[1-1]]_Synthesizer[custom]_Eva...  custom_[1-1]
# 11  Splitter[custom_[1-1]]_Synthesizer[custom]_Eva...  custom_[1-1]
# 12  Splitter[custom_[1-1]]_Synthesizer[custom]_Eva...  custom_[1-1]
# 13  Splitter[custom_[1-1]]_Synthesizer[custom]_Eva...  custom_[1-1]
# 14  Splitter[custom_[1-1]]_Synthesizer[custom]_Eva...  custom_[1-1]
#
#    Synthesizer     Evaluator           column demo-diagnostic_Property  \
# 0       custom  [columnwise]              age            Data Validity
# 1       custom  [columnwise]     capital-gain            Data Validity
# 2       custom  [columnwise]     capital-loss            Data Validity
# 3       custom  [columnwise]        education            Data Validity
# 4       custom  [columnwise]  educational-num            Data Validity
# 5       custom  [columnwise]           fnlwgt            Data Validity
# 6       custom  [columnwise]           gender            Data Validity
# 7       custom  [columnwise]   hours-per-week            Data Validity
# 8       custom  [columnwise]           income            Data Validity
# 9       custom  [columnwise]   marital-status            Data Validity
# 10      custom  [columnwise]   native-country            Data Validity
# 11      custom  [columnwise]       occupation            Data Validity
# 12      custom  [columnwise]             race            Data Validity
# 13      custom  [columnwise]     relationship            Data Validity
# 14      custom  [columnwise]        workclass            Data Validity
#
#    demo-diagnostic_Metric  demo-diagnostic_Score demo-quality_Property  \
# 0       BoundaryAdherence                    1.0         Column Shapes
# 1       BoundaryAdherence                    1.0         Column Shapes
# 2       BoundaryAdherence                    1.0         Column Shapes
# 3       CategoryAdherence                    1.0         Column Shapes
# 4       BoundaryAdherence                    1.0         Column Shapes
# 5       BoundaryAdherence                    1.0         Column Shapes
# 6       CategoryAdherence                    1.0         Column Shapes
# 7       BoundaryAdherence                    1.0         Column Shapes
# 8       CategoryAdherence                    1.0         Column Shapes
# 9       CategoryAdherence                    1.0         Column Shapes
# 10      CategoryAdherence                    1.0         Column Shapes
# 11      CategoryAdherence                    1.0         Column Shapes
# 12      CategoryAdherence                    1.0         Column Shapes
# 13      CategoryAdherence                    1.0         Column Shapes
# 14      CategoryAdherence                    1.0         Column Shapes
#
#    demo-quality_Metric  demo-quality_Score
# 0         KSComplement            0.962276
# 1         KSComplement            0.916669
# 2         KSComplement            0.952934
# 3         TVComplement            0.956952
# 4         KSComplement            0.882758
# 5         KSComplement            0.957951
# 6         TVComplement            0.997953
# 7         KSComplement            0.745886
# 8         TVComplement            0.980344
# 9         TVComplement            0.989558
# 10        TVComplement            0.992399
# 11        TVComplement            0.979909
# 12        TVComplement            0.992783
# 13        TVComplement            0.995931
# 14        TVComplement            0.984644

# %%
exec_case.get_result()[
    "Splitter[custom_[1-1]]_Synthesizer[custom]_Evaluator[demo-quality]_Reporter[rpt]"
]["[pairwise]"]
# Out:
#                                         full_expt_name      Splitter  \
# 0    Splitter[custom_[1-1]]_Synthesizer[custom]_Eva...  custom_[1-1]
# 1    Splitter[custom_[1-1]]_Synthesizer[custom]_Eva...  custom_[1-1]
# 2    Splitter[custom_[1-1]]_Synthesizer[custom]_Eva...  custom_[1-1]
# 3    Splitter[custom_[1-1]]_Synthesizer[custom]_Eva...  custom_[1-1]
# 4    Splitter[custom_[1-1]]_Synthesizer[custom]_Eva...  custom_[1-1]
# ..                                                 ...           ...
# 100  Splitter[custom_[1-1]]_Synthesizer[custom]_Eva...  custom_[1-1]
# 101  Splitter[custom_[1-1]]_Synthesizer[custom]_Eva...  custom_[1-1]
# 102  Splitter[custom_[1-1]]_Synthesizer[custom]_Eva...  custom_[1-1]
# 103  Splitter[custom_[1-1]]_Synthesizer[custom]_Eva...  custom_[1-1]
# 104  Splitter[custom_[1-1]]_Synthesizer[custom]_Eva...  custom_[1-1]
#
#     Synthesizer   Evaluator         column1          column2  \
# 0        custom  [pairwise]             age        workclass
# 1        custom  [pairwise]             age           fnlwgt
# 2        custom  [pairwise]             age        education
# 3        custom  [pairwise]             age  educational-num
# 4        custom  [pairwise]             age   marital-status
# ..          ...         ...             ...              ...
# 100      custom  [pairwise]    capital-loss   native-country
# 101      custom  [pairwise]    capital-loss           income
# 102      custom  [pairwise]  hours-per-week   native-country
# 103      custom  [pairwise]  hours-per-week           income
# 104      custom  [pairwise]  native-country           income
#
#     demo-quality_Property    demo-quality_Metric  demo-quality_Score  \
# 0      Column Pair Trends  ContingencySimilarity            0.869526
# 1      Column Pair Trends  CorrelationSimilarity            0.991312
# 2      Column Pair Trends  ContingencySimilarity            0.841399
# 3      Column Pair Trends  CorrelationSimilarity            0.982322
# 4      Column Pair Trends  ContingencySimilarity            0.739974
# ..                    ...                    ...                 ...
# 100    Column Pair Trends  ContingencySimilarity            0.006296
# 101    Column Pair Trends  ContingencySimilarity            0.006322
# 102    Column Pair Trends  ContingencySimilarity            0.649528
# 103    Column Pair Trends  ContingencySimilarity            0.630922
# 104    Column Pair Trends  ContingencySimilarity            0.963760
#
#      demo-quality_Real Correlation  demo-quality_Synthetic Correlation  \
# 0                              NaN                                 NaN
# 1                        -0.074923                           -0.057548
# 2                              NaN                                 NaN
# 3                         0.034849                            0.070204
# 4                              NaN                                 NaN
# ..                             ...                                 ...
# 100                            NaN                                 NaN
# 101                            NaN                                 NaN
# 102                            NaN                                 NaN
# 103                            NaN                                 NaN
# 104                            NaN                                 NaN
#
#     demo-quality_Error
# 0                 None
# 1                 None
# 2                 None
# 3                 None
# 4                 None
# ..                 ...
# 100               None
# 101               None
# 102               None
# 103               None
# 104               None
#
# [105 rows x 12 columns]
