# %% [markdown]
# # Environment setting / 環境設定
# Default Synthesis and Default Evaluation / 預設合成與預設評測

# %%
import os
import sys
from pathlib import Path

# 自動載入 utils / Auto-load utils
if "COLAB_GPU" in os.environ:
    url = "https://raw.githubusercontent.com/nics-tw/petsard/main/demo/utils.py"
    exec(open(url).read())
else:
    # 靜默搜尋 utils.py / Silent search for utils.py
    current = Path.cwd()
    for _ in range(5):
        if (current / "utils.py").exists():
            sys.path.insert(0, str(current))
            break
        current = current.parent

    # 匯入 utils 模組 / Import utils module
    from utils import quick_setup

# 快速設定 / Quick setup
is_colab, branch, yaml_path = quick_setup(
    yaml_file="default-synthesis-default-evaluation.yaml",
    benchmark_data=["adult-income"],
    branch="main",  # 可選，預設為 "main"
)

from petsard import Executor
# Out:
# 🚀 PETsARD v1.6.0rc1
# 📅 2025-08-05 15:56:42 UTC+8
# 📁 Subfolder: tutorial
# 📄 YAML path: petsard/demo/tutorial/default-synthesis-default-evaluation.yaml
# ⚙️ Configuration content:
# ---
# Loader:
#   data:
#     filepath: 'benchmark/adult-income.csv'
# Splitter:
#   demo:
#     num_samples: 1
#     train_split_ratio: 0.8
# Preprocessor:
#   demo:
#     method: 'default'
# Synthesizer:
#   demo:
#     method: 'default'
# Postprocessor:
#   demo:
#     method: 'default'
# Evaluator:
#   demo-diagnostic:
#     method: 'sdmetrics-diagnosticreport'
#   demo-quality:
#     method: 'sdmetrics-qualityreport'
#   demo-singlingout:
#     method: 'anonymeter-singlingout'
#   demo-linkability:
#     method: 'anonymeter-linkability'
#     aux_cols:
#       -
#         - 'age'
#         - 'marital-status'
#         - 'relationship'
#         - 'gender'
#       -
#         - 'workclass'
#         - 'educational-num'
#         - 'occupation'
#         - 'income'
#   demo-inference:
#     method: 'anonymeter-inference'
#     secret: 'income'
#   demo-classification:
#     method: 'mlutility-classification'
#     target: 'income'
# Reporter:
#   data:
#     method: 'save_data'
#     source: 'Postprocessor'
#   rpt:
#     method: 'save_report'
#     granularity:
#       - 'global'
#       - 'columnwise'
#       - 'pairwise'
#       - 'details'
# ...

# %% [markdown]
# # Execution and Result / 執行與結果

# %%
exec_case = Executor(config=yaml_path)
exec_case.run()
# Out:
# Generating report ...
#
# (1/2) Evaluating Data Validity: |██████████| 15/15 [00:00<00:00, 492.53it/s]|
# Data Validity Score: 100.0%
#
# (2/2) Evaluating Data Structure: |██████████| 1/1 [00:00<00:00, 1020.51it/s]|
# Data Structure Score: 100.0%
#
# Overall Score (Average): 100.0%
#
# Generating report ...
#
# (1/2) Evaluating Column Shapes: |██████████| 15/15 [00:00<00:00, 111.18it/s]|
# Column Shapes Score: 89.0%
#
# (2/2) Evaluating Column Pair Trends: |██████████| 105/105 [00:00<00:00, 146.84it/s]|
# Column Pair Trends Score: 81.45%
#
# Overall Score (Average): 85.22%
# Found 1620 failed queries out of 2000. Check DEBUG messages for more details.
# Reached maximum number of attempts 500000 when generating singling out queries. Returning 147 instead of the requested 2000.To avoid this, increase the number of attempts or set it to ``None`` to disable The limitation entirely.
# Attack `multivariate` could generate only 147 singling out queries out of the requested 2000. This can probably lead to an underestimate of the singling out risk.
# /Users/justyn.chen/Library/CloudStorage/Dropbox/5_Career 工作/20231016_NICS 資安院/3_工藝：PETsARD/petsard/.venv/lib/python3.11/site-packages/anonymeter/stats/confidence.py:218: UserWarning: Attack is as good or worse as baseline model. Estimated rates: attack = 0.0009585236406264672, baseline = 0.0009585236406264672. Analysis results cannot be trusted.
#   self._sanity_check()

# %%
exec_case.get_result()[
    "Loader[data]_Splitter[demo_[1-1]]_Preprocessor[demo]_Synthesizer[demo]_Postprocessor[demo]_Evaluator[demo-classification]_Reporter[rpt]"
]["[global]"]
# Out:
#                                       full_expt_name Loader    Splitter  \
# 0  Loader[data]_Splitter[demo_[1-1]]_Preprocessor...   data  demo_[1-1]
#
#   Preprocessor Synthesizer Postprocessor Evaluator  demo-diagnostic_Score  \
# 0         demo        demo          demo  [global]                    1.0
#
#    demo-diagnostic_Data Validity  demo-diagnostic_Data Structure  ...  \
# 0                            1.0                             1.0  ...
#
#    demo-inference_attack_rate_err  demo-inference_baseline_rate  \
# 0                            0.02                          0.64
#
#    demo-inference_baseline_rate_err  demo-inference_control_rate  \
# 0                              0.02                         0.72
#
#    demo-inference_control_rate_err  demo-classification_ori_mean  \
# 0                             0.02                          0.85
#
#    demo-classification_ori_std  demo-classification_syn_mean  \
# 0                         0.01                          0.76
#
#    demo-classification_syn_std  demo-classification_diff
# 0                          0.0                     -0.09
#
# [1 rows x 45 columns]

# %%
exec_case.get_result()[
    "Loader[data]_Splitter[demo_[1-1]]_Preprocessor[demo]_Synthesizer[demo]_Postprocessor[demo]_Evaluator[demo-quality]_Reporter[rpt]"
]["[columnwise]"]
# Out:
#                                        full_expt_name Loader    Splitter  \
# 0   Loader[data]_Splitter[demo_[1-1]]_Preprocessor...   data  demo_[1-1]
# 1   Loader[data]_Splitter[demo_[1-1]]_Preprocessor...   data  demo_[1-1]
# 2   Loader[data]_Splitter[demo_[1-1]]_Preprocessor...   data  demo_[1-1]
# 3   Loader[data]_Splitter[demo_[1-1]]_Preprocessor...   data  demo_[1-1]
# 4   Loader[data]_Splitter[demo_[1-1]]_Preprocessor...   data  demo_[1-1]
# 5   Loader[data]_Splitter[demo_[1-1]]_Preprocessor...   data  demo_[1-1]
# 6   Loader[data]_Splitter[demo_[1-1]]_Preprocessor...   data  demo_[1-1]
# 7   Loader[data]_Splitter[demo_[1-1]]_Preprocessor...   data  demo_[1-1]
# 8   Loader[data]_Splitter[demo_[1-1]]_Preprocessor...   data  demo_[1-1]
# 9   Loader[data]_Splitter[demo_[1-1]]_Preprocessor...   data  demo_[1-1]
# 10  Loader[data]_Splitter[demo_[1-1]]_Preprocessor...   data  demo_[1-1]
# 11  Loader[data]_Splitter[demo_[1-1]]_Preprocessor...   data  demo_[1-1]
# 12  Loader[data]_Splitter[demo_[1-1]]_Preprocessor...   data  demo_[1-1]
# 13  Loader[data]_Splitter[demo_[1-1]]_Preprocessor...   data  demo_[1-1]
# 14  Loader[data]_Splitter[demo_[1-1]]_Preprocessor...   data  demo_[1-1]
#
#    Preprocessor Synthesizer Postprocessor     Evaluator           column  \
# 0          demo        demo          demo  [columnwise]              age
# 1          demo        demo          demo  [columnwise]     capital-gain
# 2          demo        demo          demo  [columnwise]     capital-loss
# 3          demo        demo          demo  [columnwise]        education
# 4          demo        demo          demo  [columnwise]  educational-num
# 5          demo        demo          demo  [columnwise]           fnlwgt
# 6          demo        demo          demo  [columnwise]           gender
# 7          demo        demo          demo  [columnwise]   hours-per-week
# 8          demo        demo          demo  [columnwise]           income
# 9          demo        demo          demo  [columnwise]   marital-status
# 10         demo        demo          demo  [columnwise]   native-country
# 11         demo        demo          demo  [columnwise]       occupation
# 12         demo        demo          demo  [columnwise]             race
# 13         demo        demo          demo  [columnwise]     relationship
# 14         demo        demo          demo  [columnwise]        workclass
#
#    demo-diagnostic_Property demo-diagnostic_Metric  demo-diagnostic_Score  \
# 0             Data Validity      BoundaryAdherence                    1.0
# 1             Data Validity      BoundaryAdherence                    1.0
# 2             Data Validity      BoundaryAdherence                    1.0
# 3             Data Validity      CategoryAdherence                    1.0
# 4             Data Validity      BoundaryAdherence                    1.0
# 5             Data Validity      BoundaryAdherence                    1.0
# 6             Data Validity      CategoryAdherence                    1.0
# 7             Data Validity      BoundaryAdherence                    1.0
# 8             Data Validity      CategoryAdherence                    1.0
# 9             Data Validity      CategoryAdherence                    1.0
# 10            Data Validity      CategoryAdherence                    1.0
# 11            Data Validity      CategoryAdherence                    1.0
# 12            Data Validity      CategoryAdherence                    1.0
# 13            Data Validity      CategoryAdherence                    1.0
# 14            Data Validity      CategoryAdherence                    1.0
#
#    demo-quality_Property demo-quality_Metric  demo-quality_Score
# 0          Column Shapes        KSComplement            0.979653
# 1          Column Shapes        KSComplement            0.091342
# 2          Column Shapes        KSComplement            0.738489
# 3          Column Shapes        TVComplement            0.992911
# 4          Column Shapes        KSComplement            0.857958
# 5          Column Shapes        KSComplement            0.955289
# 6          Column Shapes        TVComplement            0.998669
# 7          Column Shapes        KSComplement            0.759169
# 8          Column Shapes        TVComplement            0.996750
# 9          Column Shapes        TVComplement            0.998157
# 10         Column Shapes        TVComplement            0.996340
# 11         Column Shapes        TVComplement            0.994472
# 12         Column Shapes        TVComplement            0.997517
# 13         Column Shapes        TVComplement            0.996494
# 14         Column Shapes        TVComplement            0.996622

# %%
exec_case.get_result()[
    "Loader[data]_Splitter[demo_[1-1]]_Preprocessor[demo]_Synthesizer[demo]_Postprocessor[demo]_Evaluator[demo-quality]_Reporter[rpt]"
]["[pairwise]"]
# Out:
#                                         full_expt_name Loader    Splitter  \
# 0    Loader[data]_Splitter[demo_[1-1]]_Preprocessor...   data  demo_[1-1]
# 1    Loader[data]_Splitter[demo_[1-1]]_Preprocessor...   data  demo_[1-1]
# 2    Loader[data]_Splitter[demo_[1-1]]_Preprocessor...   data  demo_[1-1]
# 3    Loader[data]_Splitter[demo_[1-1]]_Preprocessor...   data  demo_[1-1]
# 4    Loader[data]_Splitter[demo_[1-1]]_Preprocessor...   data  demo_[1-1]
# ..                                                 ...    ...         ...
# 100  Loader[data]_Splitter[demo_[1-1]]_Preprocessor...   data  demo_[1-1]
# 101  Loader[data]_Splitter[demo_[1-1]]_Preprocessor...   data  demo_[1-1]
# 102  Loader[data]_Splitter[demo_[1-1]]_Preprocessor...   data  demo_[1-1]
# 103  Loader[data]_Splitter[demo_[1-1]]_Preprocessor...   data  demo_[1-1]
# 104  Loader[data]_Splitter[demo_[1-1]]_Preprocessor...   data  demo_[1-1]
#
#     Preprocessor Synthesizer Postprocessor   Evaluator         column1  \
# 0           demo        demo          demo  [pairwise]             age
# 1           demo        demo          demo  [pairwise]             age
# 2           demo        demo          demo  [pairwise]             age
# 3           demo        demo          demo  [pairwise]             age
# 4           demo        demo          demo  [pairwise]             age
# ..           ...         ...           ...         ...             ...
# 100         demo        demo          demo  [pairwise]    capital-loss
# 101         demo        demo          demo  [pairwise]    capital-loss
# 102         demo        demo          demo  [pairwise]  hours-per-week
# 103         demo        demo          demo  [pairwise]  hours-per-week
# 104         demo        demo          demo  [pairwise]  native-country
#
#              column2 demo-quality_Property    demo-quality_Metric  \
# 0          workclass    Column Pair Trends  ContingencySimilarity
# 1             fnlwgt    Column Pair Trends  CorrelationSimilarity
# 2          education    Column Pair Trends  ContingencySimilarity
# 3    educational-num    Column Pair Trends  CorrelationSimilarity
# 4     marital-status    Column Pair Trends  ContingencySimilarity
# ..               ...                   ...                    ...
# 100   native-country    Column Pair Trends  ContingencySimilarity
# 101           income    Column Pair Trends  ContingencySimilarity
# 102   native-country    Column Pair Trends  ContingencySimilarity
# 103           income    Column Pair Trends  ContingencySimilarity
# 104           income    Column Pair Trends  ContingencySimilarity
#
#      demo-quality_Score  demo-quality_Real Correlation  \
# 0              0.920431                            NaN
# 1              0.991285                      -0.076431
# 2              0.883679                            NaN
# 3              0.975754                       0.035498
# 4              0.734113                            NaN
# ..                  ...                            ...
# 100            0.956185                            NaN
# 101            0.958181                            NaN
# 102            0.670898                            NaN
# 103            0.668441                            NaN
# 104            0.987536                            NaN
#
#      demo-quality_Synthetic Correlation
# 0                                   NaN
# 1                             -0.059001
# 2                                   NaN
# 3                              0.083991
# 4                                   NaN
# ..                                  ...
# 100                                 NaN
# 101                                 NaN
# 102                                 NaN
# 103                                 NaN
# 104                                 NaN
#
# [105 rows x 14 columns]
