# %% [markdown]
# # Environment setting / 環境設定
# Default Synthesis / 預設合成

# %%
import os
import sys
from pathlib import Path

# 自動載入 utils / Auto-load utils
if "COLAB_GPU" in os.environ:
    url = "https://raw.githubusercontent.com/nics-tw/petsard/main/demo/utils.py"
    exec(open(url).read())
else:
    # 靜默搜尋 utils.py / Silent search for utils.py
    current = Path.cwd()
    for _ in range(5):
        if (current / "utils.py").exists():
            sys.path.insert(0, str(current))
            break
        current = current.parent

    # 匯入 utils 模組 / Import utils module
    from utils import quick_setup

# 快速設定 / Quick setup
is_colab, branch, yaml_path = quick_setup(
    yaml_file="default-synthesis.yaml",
    benchmark_data=["adult-income"],
    branch="main",  # 可選，預設為 "main"
)

from petsard import Executor
# Out:
# 🚀 PETsARD v1.6.0rc1
# 📅 2025-08-05 15:19:03 UTC+8
# 📁 Subfolder: tutorial
# 📄 YAML path: petsard/demo/tutorial/default-synthesis.yaml
# ⚙️ Configuration content:
# ---
# Loader:
#   data:
#     filepath: 'benchmark/adult-income.csv'
# Preprocessor:
#   demo:
#     method: 'default'
# Synthesizer:
#   demo:
#     method: 'default' # sdv-single_table-gaussiancopula
# Postprocessor:
#   demo:
#     method: 'default'
# Reporter:
#   output:
#     method: 'save_data'
#     source: 'Postprocessor'
# ...

# %% [markdown]
# # Execution and Result / 執行與結果

# %%
exec_case = Executor(config=yaml_path)
exec_case.run()

# %%
exec_case.get_result()[
    "Loader[data]_Preprocessor[demo]_Synthesizer[demo]_Postprocessor[demo]_Reporter[output]"
]["Loader[data]_Preprocessor[demo]_Synthesizer[demo]_Postprocessor[demo]"]
# Out:
#              age         workclass         fnlwgt     education  \
# 0      45.512907           Private  105689.806340     Bachelors
# 1      30.499556  Self-emp-not-inc  142167.787202       HS-grad
# 2      30.666071           Private   70682.350975     Bachelors
# 3      35.605125           Private  217418.278622     Assoc-voc
# 4      31.010976           Private   85354.010038       HS-grad
# ...          ...               ...            ...           ...
# 28553  45.744611           Private  204517.737385  Some-college
# 28554  40.147285           Private  215714.678949           9th
# 28555  37.076590           Private  300336.661167     Bachelors
# 28556  20.479051           Private  283649.207866       HS-grad
# 28557  33.254986           Private  117875.685606       HS-grad
#
#        educational-num      marital-status       occupation    relationship  \
# 0            12.105630  Married-civ-spouse     Tech-support  Other-relative
# 1             9.944627       Never-married    Other-service         Husband
# 2            11.984638  Married-civ-spouse     Craft-repair         Husband
# 3             8.728909       Never-married            Sales       Own-child
# 4            11.887584       Never-married     Adm-clerical       Own-child
# ...                ...                 ...              ...             ...
# 28553        10.556458  Married-civ-spouse  Protective-serv         Husband
# 28554         8.935874       Never-married     Craft-repair         Husband
# 28555        11.688683       Never-married     Adm-clerical            Wife
# 28556        12.262466       Never-married  Exec-managerial         Husband
# 28557        11.186965       Never-married  Exec-managerial       Unmarried
#
#                      race  gender  capital-gain  capital-loss  hours-per-week  \
# 0                   White  Female           0.0           0.0       38.749756
# 1                   White  Female           0.0           0.0       35.750808
# 2                   White    Male           0.0           0.0       35.629283
# 3                   White    Male           0.0           0.0       36.473109
# 4                   Black  Female           0.0           0.0       51.820505
# ...                   ...     ...           ...           ...             ...
# 28553               White    Male           0.0           0.0       50.428578
# 28554               White  Female           0.0           0.0       47.407431
# 28555               White    Male           0.0           0.0       51.664408
# 28556               White  Female           0.0           0.0       34.931744
# 28557  Asian-Pac-Islander    Male           0.0           0.0       45.865108
#
#       native-country income
# 0      United-States  <=50K
# 1      United-States  <=50K
# 2      United-States   >50K
# 3      United-States  <=50K
# 4      United-States   >50K
# ...              ...    ...
# 28553  United-States  <=50K
# 28554         Mexico  <=50K
# 28555  United-States  <=50K
# 28556  United-States  <=50K
# 28557  United-States  <=50K
#
# [28558 rows x 15 columns]
