# %% [markdown]
# # Environment setting / 環境設定
# Data Description / 資料描述

# %%
import os
import sys
from pathlib import Path

# 自動載入 utils / Auto-load utils
if "COLAB_GPU" in os.environ:
    url = "https://raw.githubusercontent.com/nics-tw/petsard/main/demo/utils.py"
    exec(open(url).read())
else:
    # 靜默搜尋 utils.py / Silent search for utils.py
    current = Path.cwd()
    for _ in range(5):
        if (current / "utils.py").exists():
            sys.path.insert(0, str(current))
            break
        current = current.parent

    # 匯入 utils 模組 / Import utils module
    from utils import quick_setup

# 快速設定 / Quick setup
is_colab, branch, yaml_path = quick_setup(
    yaml_file="data-description.yaml",
    benchmark_data=[
        "adult-income",
    ],
    branch="main",  # 可選，預設為 "main"
)

from petsard import Executor
# Out:
# 🚀 PETsARD v1.5.1
# 📅 2025-07-31 13:33:16 UTC+8
# 📁 Subfolder: tutorial/use-cases
# 📄 YAML path: petsard/demo/tutorial/use-cases/data-description.yaml
# ⚙️ Configuration content:
# ---
# Loader:
#   data:
#     filepath: 'benchmark/adult-income.csv'
# Describer:
#   summary:
#     method: 'default'
# Reporter:
#   save_report_global:
#     method: 'save_report'
#     granularity: 'global'
#   save_report_columnwise:
#     method: 'save_report'
#     granularity: 'columnwise'
#   save_report_pairwise:
#     method: 'save_report'
#     granularity: 'pairwise'
# ...

# %% [markdown]
# # Execution and Result / 執行與結果

# %%
exec_case = Executor(config=yaml_path)
exec_case.run()
# Out:
# Now is petsard[Report]_[global] save to csv...
# Now is petsard[Report]_[columnwise] save to csv...
# Now is petsard[Report]_[pairwise] save to csv...

# %%
exec_case.get_result()["Loader[data]_Describer[summary]_Reporter[save_report_global]"][
    "[global]"
]
# Out:
#                    full_expt_name Loader Describer  summary_row_count  \
# 0  Loader[data]_Describer[global]   data  [global]              48842
#
#    summary_col_count  summary_na_count
# 0                 15                 0

# %%
exec_case.get_result()[
    "Loader[data]_Describer[summary]_Reporter[save_report_columnwise]"
]["[columnwise]"]
# Out:
#                         full_expt_name Loader     Describer           column  \
# 0   Loader[data]_Describer[columnwise]   data  [columnwise]              age
# 1   Loader[data]_Describer[columnwise]   data  [columnwise]           fnlwgt
# 2   Loader[data]_Describer[columnwise]   data  [columnwise]  educational-num
# 3   Loader[data]_Describer[columnwise]   data  [columnwise]     capital-gain
# 4   Loader[data]_Describer[columnwise]   data  [columnwise]     capital-loss
# 5   Loader[data]_Describer[columnwise]   data  [columnwise]   hours-per-week
# 6   Loader[data]_Describer[columnwise]   data  [columnwise]        workclass
# 7   Loader[data]_Describer[columnwise]   data  [columnwise]        education
# 8   Loader[data]_Describer[columnwise]   data  [columnwise]   marital-status
# 9   Loader[data]_Describer[columnwise]   data  [columnwise]       occupation
# 10  Loader[data]_Describer[columnwise]   data  [columnwise]     relationship
# 11  Loader[data]_Describer[columnwise]   data  [columnwise]             race
# 12  Loader[data]_Describer[columnwise]   data  [columnwise]           gender
# 13  Loader[data]_Describer[columnwise]   data  [columnwise]   native-country
# 14  Loader[data]_Describer[columnwise]   data  [columnwise]           income
#
#     summary_mean  summary_median  summary_std  summary_min  summary_max  \
# 0          38.64            37.0        13.71         17.0         90.0
# 1      189664.13        178144.5    105604.03      12285.0    1490400.0
# 2          10.08            10.0         2.57          1.0         16.0
# 3        1079.07             0.0      7452.02          0.0      99999.0
# 4          87.50             0.0       403.00          0.0       4356.0
# 5          40.42            40.0        12.39          1.0         99.0
# 6            NaN             NaN          NaN          NaN          NaN
# 7            NaN             NaN          NaN          NaN          NaN
# 8            NaN             NaN          NaN          NaN          NaN
# 9            NaN             NaN          NaN          NaN          NaN
# 10           NaN             NaN          NaN          NaN          NaN
# 11           NaN             NaN          NaN          NaN          NaN
# 12           NaN             NaN          NaN          NaN          NaN
# 13           NaN             NaN          NaN          NaN          NaN
# 14           NaN             NaN          NaN          NaN          NaN
#
#     summary_kurtosis  summary_skew  summary_q1  summary_q3  summary_na_count  \
# 0              -0.18          0.56        28.0        48.0               0.0
# 1               6.06          1.44    117550.5    237642.0               0.0
# 2               0.63         -0.32         9.0        12.0               0.0
# 3             152.69         11.89         0.0         0.0               0.0
# 4              20.01          4.57         0.0         0.0               0.0
# 5               2.95          0.24        40.0        45.0               0.0
# 6                NaN           NaN         NaN         NaN               0.0
# 7                NaN           NaN         NaN         NaN               0.0
# 8                NaN           NaN         NaN         NaN               0.0
# 9                NaN           NaN         NaN         NaN               0.0
# 10               NaN           NaN         NaN         NaN               0.0
# 11               NaN           NaN         NaN         NaN               0.0
# 12               NaN           NaN         NaN         NaN               0.0
# 13               NaN           NaN         NaN         NaN               0.0
# 14               NaN           NaN         NaN         NaN               0.0
#
#    summary_nunique
# 0             <NA>
# 1             <NA>
# 2             <NA>
# 3             <NA>
# 4             <NA>
# 5             <NA>
# 6                9
# 7               16
# 8                7
# 9               15
# 10               6
# 11               5
# 12               2
# 13              42
# 14               2

# %%
exec_case.get_result()[
    "Loader[data]_Describer[summary]_Reporter[save_report_pairwise]"
]["[pairwise]"]
# Out:
#                       full_expt_name Loader   Describer  summary_column1  \
# 0   Loader[data]_Describer[pairwise]   data  [pairwise]              age
# 1   Loader[data]_Describer[pairwise]   data  [pairwise]     capital-gain
# 2   Loader[data]_Describer[pairwise]   data  [pairwise]     capital-gain
# 3   Loader[data]_Describer[pairwise]   data  [pairwise]     capital-gain
# 4   Loader[data]_Describer[pairwise]   data  [pairwise]     capital-gain
# 5   Loader[data]_Describer[pairwise]   data  [pairwise]     capital-loss
# 6   Loader[data]_Describer[pairwise]   data  [pairwise]     capital-loss
# 7   Loader[data]_Describer[pairwise]   data  [pairwise]     capital-loss
# 8   Loader[data]_Describer[pairwise]   data  [pairwise]     capital-loss
# 9   Loader[data]_Describer[pairwise]   data  [pairwise]     capital-loss
# 10  Loader[data]_Describer[pairwise]   data  [pairwise]  educational-num
# 11  Loader[data]_Describer[pairwise]   data  [pairwise]  educational-num
# 12  Loader[data]_Describer[pairwise]   data  [pairwise]  educational-num
# 13  Loader[data]_Describer[pairwise]   data  [pairwise]           fnlwgt
# 14  Loader[data]_Describer[pairwise]   data  [pairwise]           fnlwgt
# 15  Loader[data]_Describer[pairwise]   data  [pairwise]   hours-per-week
# 16  Loader[data]_Describer[pairwise]   data  [pairwise]   hours-per-week
# 17  Loader[data]_Describer[pairwise]   data  [pairwise]   hours-per-week
# 18  Loader[data]_Describer[pairwise]   data  [pairwise]   hours-per-week
# 19  Loader[data]_Describer[pairwise]   data  [pairwise]   hours-per-week
# 20  Loader[data]_Describer[pairwise]   data  [pairwise]   hours-per-week
#
#     summary_column2  summary_corr
# 0               age      1.000000
# 1               age      0.077229
# 2      capital-gain      1.000000
# 3   educational-num      0.125146
# 4            fnlwgt     -0.003706
# 5               age      0.056944
# 6      capital-gain     -0.031441
# 7      capital-loss      1.000000
# 8   educational-num      0.080972
# 9            fnlwgt     -0.004366
# 10              age      0.030940
# 11  educational-num      1.000000
# 12           fnlwgt     -0.038761
# 13              age     -0.076628
# 14           fnlwgt      1.000000
# 15              age      0.071558
# 16     capital-gain      0.082157
# 17     capital-loss      0.054467
# 18  educational-num      0.143689
# 19           fnlwgt     -0.013519
# 20   hours-per-week      1.000000
