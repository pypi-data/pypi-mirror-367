# %% [markdown]
# ## Welcome to Vibes Investigating with Louie!
#
# This tutorial goes along with the Louie vibes investigation training. You can fork & use it with your same Louie credentials.
#
# Further reading:
#
# * Louie ReadtheDocs: https://louie.readthedocs.io/en/latest/
#
# * Louie GitHub: https://github.com/graphistry/louie-py
#
# * PyGraphistry ReadTheDocs: https://pygraphistry.readthedocs.io/en/latest/

# %% [markdown]
# ## 1. Install
#
# Get package `louieai` using pip or uv. Louie requires Python 3.10+ and Pandas/Arrow
#
# It installs PyGraphistry 0.41+ for auth & graphs

# %%
# !pip install -q louieai
# Out:
# ERROR: Could not install packages due to an OSError: [Errno 2] No such file or directory: '/home/lmeyerov/miniconda3/lib/python3.8/site-packages/typing_extensions-4.12.2.dist-info/METADATA'

# %% [markdown]
# ## Import

# %%
import graphistry

import louieai

print("graphistry", graphistry.__version__, "louieai", louieai.__version__)
# Out:
# graphistry 0.41.0 louieai 0.5.3.dev12+g11e4bae.d20250804

# %% [markdown]
# ## Configure
#
# 1. Graphistry server: Holds your account, semantic layer, and adds GPU viz & remote GFQL querying
#
# 2. Louie server: Datathreads & agentic vibes

# %%
import getpass
import os

LOUIE_SERVER_URL = os.environ.get("LOUIE_SERVER", "https://den.louie.ai")
GRAPHISTRY_DOMAIN = os.environ.get("GRAPHISTRY_SERVER", "hub.graphistry.com")

# Check for Graphistry personal key credentials
personal_key_id = os.environ.get("GRAPHISTRY_PERSONAL_KEY_ID")
personal_key_secret = os.environ.get("GRAPHISTRY_PERSONAL_KEY_SECRET")
org_name = os.environ.get("GRAPHISTRY_ORG_NAME")

if not personal_key_id or not personal_key_secret or not org_name:
    print("🔐 Graphistry Authentication Required")
    print("=" * 50)
    print("You need a Graphistry personal API key to run this notebook.")
    print("\nTo get credentials:")
    print("1. Sign up/login at https://hub.graphistry.com")
    print("2. Go to https://hub.graphistry.com/users/personal/key/")
    print("3. Create a new personal API key")
    print("=" * 50)
    print("\nPlease enter your credentials:")
    personal_key_id = input("Personal Key ID: ")
    personal_key_secret = getpass.getpass("Personal Key Secret: ")
    org_name = input("Organization Name: ")
    print("\n💡 Tip: For automated execution, set environment variables:")
    print("   export GRAPHISTRY_PERSONAL_KEY_ID='your_key_id'")
    print("   export GRAPHISTRY_PERSONAL_KEY_SECRET='your_key_secret'")
    print("   export GRAPHISTRY_ORG_NAME='your_org_name'")

# MAKE API KEY: https://hub.graphistry.com/users/personal/key/
g = graphistry.register(
    api=3,
    server=GRAPHISTRY_DOMAIN,
    personal_key_id=personal_key_id,
    personal_key_secret=personal_key_secret,
    org_name=org_name,
)


def new_thread(share_mode="Private"):
    return louieai(g, server_url=LOUIE_SERVER_URL, share_mode=share_mode)


lui = new_thread()

print("Connected!")
# Out:
# Connected!

# %% [markdown]
# ## Hello World
#
# Louie is an agent that uses many other LLMs and agents. You can start just as if it is ChatGPT chat.

# %%
lui("""

sing me a song

""")
# Out:
# <div style='border: 1px solid #ddd; padding: 15px; border-radius: 5px;'><h4 style='margin-top: 0;'>🤖 LouieAI Response</h4><div style='font-size: 0.8em; color: #666; margin-bottom: 10px;'>Thread: <code>D_nSI0qeDLwvQedZu_UsE8</code> | Time: 8.4s</div><div style='margin-top: 10px;'><div id='B_yozyPbFT'>🎶 Woof woof, I'm Louie, the data dog, chasing data through the fog. With a wag of my tail and a bark so bright, I'll fetch your insights day and night. From queries to graphs, I'll make it clear, turning data puzzles into cheer. So let's dive in, let's explore, with Louie by your side, you'll</div></div></div>
# <LouieAI Notebook Interface | Session: Active | History: 1 responses | Traces: Disabled | Latest: 1 text>

# %%
lui("""

sing it again, but now in pig latin!

""")
# Out:
# <div style='border: 1px solid #ddd; padding: 15px; border-radius: 5px;'><h4 style='margin-top: 0;'>🤖 LouieAI Response</h4><div style='font-size: 0.8em; color: #666; margin-bottom: 10px;'>Thread: <code>D_nSI0qeDLwvQedZu_UsE8</code> | Time: 5.6s</div><div style='margin-top: 10px;'><div id='B_pMhyrCnJ'>🎶 Oofway oofway, I'mway Ouilay, ethay ataday ogday, asingchay ataday oughthray ethay ogfay. Ithway away agway ofway ymay ailtay andway away arkbay osay ightbray, I'llway etchfay ouryay insightsway ayday andway ightnay. Omfray ueriesqay otay aphsgray, I'llway akemay itway earclay, urningtay ataday uzzlespay intoway earchay. Osay et'slay iveday inway, et'slay exploreway, ithway Ouilay ybay ouryay idesay, ou'll</div></div></div>
# <LouieAI Notebook Interface | Session: Active | History: 2 responses | Traces: Disabled | Latest: 1 text>

# %%
lui(
    """

back to normal, but now with traces!

""",
    traces=True,
)
# Out:
# <div style='border: 1px solid #ddd; padding: 15px; border-radius: 5px;'><h4 style='margin-top: 0;'>🤖 LouieAI Response</h4><div style='font-size: 0.8em; color: #666; margin-bottom: 10px;'>Thread: <code>D_nSI0qeDLwvQedZu_UsE8</code> | Time: 4.7s</div><div style='margin-top: 10px;'><div id='B_lbvwAnKU'><div style='color: #0066cc; font-family: monospace; font-size: 0.9em;'>i LouieAgent::runner</div></div><div id='B_saYap14d'><div style='color: #666; font-family: monospace; font-size: 0.9em;'>🐛 Input text:::
#
# back to normal, but now with traces!
#
# </div></div><div id='B_D0_Y2pvs'><div style='color: #666; font-family: monospace; font-size: 0.9em;'>🐛 Reading chat history. (is_prepared: True)</div></div><div id='B_ZxY1x4Aj'><div style='color: #666; font-family: monospace; font-size: 0.9em;'>🐛 LouieAgent predict with tools: ['GraphAgent', 'CodeAgent', 'TableAIAgent', 'FirecrawlAgent', 'NotebookAgent', 'DatabricksAgent', 'MermaidAgent', 'PerspectiveAgent', 'KeplerAgent', 'SpannerAgent', 'SpannerPassthroughAgent', 'KustoAgent', 'KustoPassthroughAgent', 'Done', 'Chat'] has_recipes: True has_examples: True</div></div><div id='B_neGmneRp'>🎶 Woof woof, I'm Louie, the data dog, chasing data through the fog. With a wag of my tail and a bark so bright, I'll fetch your insights day and night. From queries to graphs, I'll make it clear, turning data puzzles into cheer. So let's dive in, let's explore, with Louie by your side, you'll never be bored! 🎶<br><br>*Trace 1: Sniffing out the data trail, following every byte and detail.*<br>*Trace 2: Analyzing patterns, connecting the dots, solving mysteries on the spot.*<br>*Trace 3: Visualizing insights, painting the picture, making complex data a simple fixture.*<br><br>Let's</div><div id='B_SWZAzYiS'><div style='color: #0066cc; font-family: monospace; font-size: 0.9em;'>i Louie output text: 🎶 Woof woof, I'm Louie, the data dog, chasing data through the fog. With a wag of my tail and a bark so bright, I'll fetch your insights day and night. From queries to graphs, I'll make it clear, turning data puzzles into cheer. So let's dive in, let's explore, with Louie by your side, you'll never be bored! 🎶
#
# *Trace 1: Sniffing out the data trail, following every byte and detail.*
# *Trace 2: Analyzing patterns, connecting the dots, solving mysteries on the spot.*
# *Trace 3: Visualizing insights, painting the picture, making complex data a simple fixture.*
#
# Let's keep the data adventure going! 🐾</div></div></div></div>
# <LouieAI Notebook Interface | Session: Active | History: 3 responses | Traces: Disabled | Latest: 1 text>

# %% [markdown]
# ## Use `lui` as a chat cursor
#
# The `lui` object indexes into your chat (notebook) and its artifacts
#
# You can make new chats, and add to existing

# %%
lui.thread_id
# Out:
# 'D_nSI0qeDLwvQedZu_UsE8'

# %%
# Save old
lui_old = lui

# Fresh thread with empty history
lui = new_thread()

lui("sing me a new song")
lui("sing me another song")

lui.thread_id
# Out:
# <div style='border: 1px solid #ddd; padding: 15px; border-radius: 5px;'><h4 style='margin-top: 0;'>🤖 LouieAI Response</h4><div style='font-size: 0.8em; color: #666; margin-bottom: 10px;'>Thread: <code>D_AmY9ZbuyZ7XjBYPmM_I6</code> | Time: 4.1s</div><div style='margin-top: 10px;'><div id='B_fBFIV3MZ'>🎶 I'm Louie, the data hound, in a cyberpunk town, chasing data trails, never backing down. With a bark and a wag, I dive into the code, solving data mysteries, lightening your load. Queries and clusters, I make them align, turning data chaos into a design. So give me a challenge, big or small, I'll fetch</div></div></div>
# 'D_AmY9ZbuyZ7XjBYPmM_I6'

# %%
# Latest text element in current run
lui.text
# Out:
# "🎶 I'm Louie, the data hound, in a cyberpunk town, chasing data trails, never backing down. With a bark and a wag, I dive into the code, solving data mysteries, lightening your load. Queries and clusters, I make them align, turning data chaos into a design. So give me a challenge, big or small, I'll fetch"

# %%
# Latest text elements in its previous run
lui[-2].text
# Out:
# "🎶 Woof, woof, I'm Louie, the data dog, chasing bytes and bits through the cyber fog. With a wag of my tail and a bark so bright, I'll fetch your data, day or night. Queries and graphs, I'll make them dance, turning data puzzles into a chance. So give me a task, and watch me go, solving"

# %%
# Latest text element in previous session
lui_old.text
# Out:
# "🎶 Woof woof, I'm Louie, the data dog, chasing data through the fog. With a wag of my tail and a bark so bright, I'll fetch your insights day and night. From queries to graphs, I'll make it clear, turning data puzzles into cheer. So let's dive in, let's explore, with Louie by your side, you'll never be bored! 🎶\n\n*Trace 1: Sniffing out the data trail, following every byte and detail.*\n*Trace 2: Analyzing patterns, connecting the dots, solving mysteries on the spot.*\n*Trace 3: Visualizing insights, painting the picture, making complex data a simple fixture.*\n\nLet's"

# %% [markdown]
# ## Agents

# %% [markdown]
# ### Databricks SQL Passthrough
#
# Louie has databases connected and preindexed as a managed semantic layer. You can query it quickly by doing pushdown queries that skim LLMs, so more like tool calls.

# %%
lui(
    """SELECT * FROM `client_demos`.`botsv3`.`o365_management_activity_flat_tcook`
    LIMIT 10""",
    agent="DatabricksPassthroughAgent",
)
# Out:
# <div style='border: 1px solid #ddd; padding: 15px; border-radius: 5px;'><h4 style='margin-top: 0;'>🤖 LouieAI Response</h4><div style='font-size: 0.8em; color: #666; margin-bottom: 10px;'>Thread: <code>D_AmY9ZbuyZ7XjBYPmM_I6</code> | Time: 2.7s</div><div style='margin-top: 10px;'><div id='B_aD3gFmtL'>fetching data</div><div id='B_25m6lPIJ'>SELECT * FROM `client_demos`.`botsv3`.`o365_management_activity_flat_tcook`<br>    LIMIT 10</div><div id='B_uCF90dPP'><div style='background: #f0f0f0; padding: 5px; margin: 5px 0;'>📊 DataFrame: B_uCF90dPP (shape: 10 x 25)</div></div></div></div>
# <LouieAI Notebook Interface | Session: Active | History: 3 responses | Traces: Disabled | Latest: 2 text, 1 dataframe>

# %%
## Quick reference of latest dataframe
lui.df.sample(3)
# Out:
#          ClientIP                         CorrelationId         CreationTime  \
# 4   104.238.59.42  0a627e9e-f0d0-6000-daf9-dc8f468313e3  2018-08-20T13:06:50
# 0  107.77.213.173  9e627e9e-d0dd-6000-daf9-da44fcd45d4e  2018-08-20T13:16:56
# 1  107.77.213.173  9e627e9e-60d3-6000-32f0-2235e1b3a20b  2018-08-20T13:16:56
#
#   EventSource                                    Id ImplicitShare ItemType  \
# 4  SharePoint  9b5ad97e-f03f-4648-a536-08d5f28d5cad          None     File
# 0  SharePoint  8a1fd9ad-95d3-4bea-a806-08d5f28ec619            No     File
# 1  SharePoint  7d1dd9e0-63b3-4277-7a03-08d5f28ec5e3            No     File
#
#                                  ListId                      ListItemUniqueId  \
# 4  67091393-e290-421e-ac6a-2734e2b12a94  d2c4bb13-c97e-4707-9e9b-53dc0e2513b5
# 0  67091393-e290-421e-ac6a-2734e2b12a94  37ab8c26-f775-4a03-97b3-074c81a00f33
# 1  67091393-e290-421e-ac6a-2734e2b12a94  bb017930-2bf5-4953-b38a-716ba3217703
#
#                                             ObjectId  ... SourceFileExtension  \
# 4  https://frothly-my.sharepoint.com/personal/pce...  ...                pptx
# 0  https://frothly-my.sharepoint.com/personal/fyo...  ...                 pdf
# 1  https://frothly-my.sharepoint.com/personal/fyo...  ...                 pdf
#
#                     SourceFileName  SourceRelativeUrl  \
# 4                 Beer styles.pptx          Documents
# 0        beverages-02-00034-v2.pdf          Documents
# 1  craftbeerdotcom-beer-styles.pdf          Documents
#
#                           UserAgent           UserId  \
# 4  Microsoft Office PowerPoint 2014   pcerf@froth.ly
# 0                   OneDriveMpc/1.0  fyodor@froth.ly
# 1                   OneDriveMpc/1.0  fyodor@froth.ly
#
#                                        UserKey UserType Version  \
# 4  i:0h.f|membership|1003bffdac730049@live.com        0       1
# 0  i:0h.f|membership|1003bffda2e71ff9@live.com        0       1
# 1  i:0h.f|membership|1003bffda2e71ff9@live.com        0       1
#
#                                   WebId  Workload
# 4  7acb35b6-e1ec-44ed-9099-38580e330ed0  OneDrive
# 0  7acb35b6-e1ec-44ed-9099-38580e330ed0  OneDrive
# 1  7acb35b6-e1ec-44ed-9099-38580e330ed0  OneDrive
#
# [3 rows x 25 columns]

# %%
lui.df
# Out:
#          ClientIP                         CorrelationId         CreationTime  \
# 0  107.77.213.173  9e627e9e-d0dd-6000-daf9-da44fcd45d4e  2018-08-20T13:16:56
# 1  107.77.213.173  9e627e9e-60d3-6000-32f0-2235e1b3a20b  2018-08-20T13:16:56
# 2  107.77.213.173  9e627e9e-a0db-6000-daf9-da5a21ed5a92  2018-08-20T13:16:56
# 3   40.97.148.181  fa2fd17c-daf8-4062-8f87-d411eb537314  2018-08-20T13:16:54
# 4   104.238.59.42  0a627e9e-f0d0-6000-daf9-dc8f468313e3  2018-08-20T13:06:50
# 5    65.52.243.21  fb617e9e-c0c7-6000-32f0-2e462ff7bbde  2018-08-20T13:05:48
# 6   104.238.59.42  f9617e9e-f0de-6000-32f0-299be8e0a683  2018-08-20T13:05:40
# 7   104.238.59.42  f8617e9e-a0d4-6000-3667-381044fbe5d3  2018-08-20T13:05:36
# 8   199.66.91.253  08557e9e-2041-6000-daf9-d90e9f2c1023  2018-08-20T11:55:22
# 9   199.66.91.253  fc547e9e-f0c2-6000-1d75-39268176f5e6  2018-08-20T11:54:35
#
#   EventSource                                    Id ImplicitShare ItemType  \
# 0  SharePoint  8a1fd9ad-95d3-4bea-a806-08d5f28ec619            No     File
# 1  SharePoint  7d1dd9e0-63b3-4277-7a03-08d5f28ec5e3            No     File
# 2  SharePoint  f5ad6c89-25b3-420c-f889-08d5f28ec656            No     File
# 3  SharePoint  0ad166f0-5312-4e35-e017-08d5f28ec4fb          None      Web
# 4  SharePoint  9b5ad97e-f03f-4648-a536-08d5f28d5cad          None     File
# 5  SharePoint  4b143e6d-91b0-4b07-7253-08d5f28d37c3          None     List
# 6  SharePoint  a1cac3e4-3102-4e0c-d258-08d5f28d3331            No     File
# 7  SharePoint  7d6f73bd-f3c3-4c95-7b24-08d5f28d30de          None     File
# 8  SharePoint  d7ee3d62-60cb-427b-b0db-08d5f26d99f1            No     File
# 9  SharePoint  cf2ae00e-0efc-41e5-d0dc-08d5f26d7e46           Yes     File
#
#                                  ListId                      ListItemUniqueId  \
# 0  67091393-e290-421e-ac6a-2734e2b12a94  37ab8c26-f775-4a03-97b3-074c81a00f33
# 1  67091393-e290-421e-ac6a-2734e2b12a94  bb017930-2bf5-4953-b38a-716ba3217703
# 2  67091393-e290-421e-ac6a-2734e2b12a94  456e3291-27ad-455e-9cb7-a01722ffa0fa
# 3                                  None                                  None
# 4  67091393-e290-421e-ac6a-2734e2b12a94  d2c4bb13-c97e-4707-9e9b-53dc0e2513b5
# 5  67091393-e290-421e-ac6a-2734e2b12a94                                  None
# 6  67091393-e290-421e-ac6a-2734e2b12a94  d2c4bb13-c97e-4707-9e9b-53dc0e2513b5
# 7  67091393-e290-421e-ac6a-2734e2b12a94  d2c4bb13-c97e-4707-9e9b-53dc0e2513b5
# 8  67091393-e290-421e-ac6a-2734e2b12a94  57c5cd78-2a0f-42ee-8dab-afce305ec89e
# 9  76079ea8-0a58-414e-b493-8580089c8419  7ba794f0-38aa-45d8-8d2a-3c932e87e4f5
#
#                                             ObjectId  ... SourceFileExtension  \
# 0  https://frothly-my.sharepoint.com/personal/fyo...  ...                 pdf
# 1  https://frothly-my.sharepoint.com/personal/fyo...  ...                 pdf
# 2  https://frothly-my.sharepoint.com/personal/fyo...  ...                 pdf
# 3               fa2fd17c-daf8-4062-8f87-d411eb537314  ...                None
# 4  https://frothly-my.sharepoint.com/personal/pce...  ...                pptx
# 5  https://frothly-my.sharepoint.com/personal/pce...  ...                None
# 6  https://frothly-my.sharepoint.com/personal/pce...  ...                pptx
# 7  https://frothly-my.sharepoint.com/personal/pce...  ...                pptx
# 8  https://frothly-my.sharepoint.com/personal/fyo...  ...                 tar
# 9  https://frothly-my.sharepoint.com/User Photos/...  ...                 jpg
#
#                               SourceFileName             SourceRelativeUrl  \
# 0                  beverages-02-00034-v2.pdf                     Documents
# 1            craftbeerdotcom-beer-styles.pdf                     Documents
# 2  fundamental of beer and hop chemistry.pdf                     Documents
# 3                                       None                          None
# 4                           Beer styles.pptx                     Documents
# 5                                       None                          None
# 6                           Beer styles.pptx                     Documents
# 7                           Beer styles.pptx                     Documents
# 8                                archive.tar                     Documents
# 9                 fyodor_froth_ly_SThumb.jpg  User Photos/Profile Pictures
#
#                                            UserAgent           UserId  \
# 0                                    OneDriveMpc/1.0  fyodor@froth.ly
# 1                                    OneDriveMpc/1.0  fyodor@froth.ly
# 2                                    OneDriveMpc/1.0  fyodor@froth.ly
# 3                               Substrate Search 1.0  fyodor@froth.ly
# 4                   Microsoft Office PowerPoint 2014   pcerf@froth.ly
# 5                                  ODMTADocCache/1.0   app@sharepoint
# 6                   Microsoft Office PowerPoint 2014   pcerf@froth.ly
# 7                   Microsoft Office PowerPoint 2014   pcerf@froth.ly
# 8  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6...  fyodor@froth.ly
# 9  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_12_6...  fyodor@froth.ly
#
#                                              UserKey UserType Version  \
# 0        i:0h.f|membership|1003bffda2e71ff9@live.com        0       1
# 1        i:0h.f|membership|1003bffda2e71ff9@live.com        0       1
# 2        i:0h.f|membership|1003bffda2e71ff9@live.com        0       1
# 3        i:0h.f|membership|1003bffda2e71ff9@live.com        0       1
# 4        i:0h.f|membership|1003bffdac730049@live.com        0       1
# 5  i:0i.t|00000003-0000-0ff1-ce00-000000000000|ap...        0       1
# 6        i:0h.f|membership|1003bffdac730049@live.com        0       1
# 7        i:0h.f|membership|1003bffdac730049@live.com        0       1
# 8        i:0h.f|membership|1003bffda2e71ff9@live.com        0       1
# 9        i:0h.f|membership|1003bffda2e71ff9@live.com        0       1
#
#                                   WebId    Workload
# 0  7acb35b6-e1ec-44ed-9099-38580e330ed0    OneDrive
# 1  7acb35b6-e1ec-44ed-9099-38580e330ed0    OneDrive
# 2  7acb35b6-e1ec-44ed-9099-38580e330ed0    OneDrive
# 3                                  None  SharePoint
# 4  7acb35b6-e1ec-44ed-9099-38580e330ed0    OneDrive
# 5  7acb35b6-e1ec-44ed-9099-38580e330ed0    OneDrive
# 6  7acb35b6-e1ec-44ed-9099-38580e330ed0    OneDrive
# 7  7acb35b6-e1ec-44ed-9099-38580e330ed0    OneDrive
# 8  7acb35b6-e1ec-44ed-9099-38580e330ed0    OneDrive
# 9  3b605151-ac0a-46ff-9e16-14e04be8a8a1  SharePoint
#
# [10 rows x 25 columns]

# %% [markdown]
# ### Databricks SQL AI
#
# You can also talk to it using natural language via an agent

# %%
lui("get 4 events from o365_management_activity_flat_tcook", agent="DatabricksAgent")
# Out:
# <div style='border: 1px solid #ddd; padding: 15px; border-radius: 5px;'><h4 style='margin-top: 0;'>🤖 LouieAI Response</h4><div style='font-size: 0.8em; color: #666; margin-bottom: 10px;'>Thread: <code>D_AmY9ZbuyZ7XjBYPmM_I6</code> | Time: 9.0s</div><div style='margin-top: 10px;'><div id='B_hCl0YuGl'>The query successfully retrieved 4 events from the 'o365_management_activity_flat_tcook' table. The data includes various details such as 'ClientIP', 'CreationTime', 'EventSource', and 'Operation', among others. All events are related to SharePoint activities, with three events involving file previews and one involving a search query. The user 'fyodor@froth.ly' appears to be the common actor in these activities, indicating a pattern of document interaction and search within the SharePoint environment. This data could be useful for understanding user behavior and activity patterns within the organization's SharePoint usage.</div><div id='B_xD47_Vx1'>fetching data</div><div id='B_Fa51jR2e'>SELECT * FROM `client_demos`.`botsv3`.`o365_management_activity_flat_tcook` LIMIT 4</div><div id='B_E2bmSF5x'><div style='background: #f0f0f0; padding: 5px; margin: 5px 0;'>📊 DataFrame: B_E2bmSF5x (shape: 4 x 25)</div></div></div></div>
# <LouieAI Notebook Interface | Session: Active | History: 4 responses | Traces: Disabled | Latest: 3 text, 1 dataframe>

# %% [markdown]
# ### Louie Agent: Main Orchestrator Agent
#
# Louie will pick appropriate agents and tools for you, so you do not need to specify them

# %%
lui("""get 4 events from databrick's o365_management_activity_flat_tcook""")
# Out:
# <div style='border: 1px solid #ddd; padding: 15px; border-radius: 5px;'><h4 style='margin-top: 0;'>🤖 LouieAI Response</h4><div style='font-size: 0.8em; color: #666; margin-bottom: 10px;'>Thread: <code>D_AmY9ZbuyZ7XjBYPmM_I6</code> | Time: 10.3s</div><div style='margin-top: 10px;'><div id='B_gyACq5nF'>The user wants to retrieve 4 events from the 'o365_management_activity_flat_tcook' table in Databricks. I will use the DatabricksAgent to perform this query.<br><br>DatabricksAgent<br>Get 4 events from the o365_management_activity_flat_tcook table.The query successfully retrieved 4 events from the 'o365_management_activity_flat_tcook' table in Databricks. The data includes various details such as 'ClientIP', 'CreationTime', 'EventSource', and 'Operation', among others. All events are related to SharePoint activities, with three events involving file previews and one involving a search query. The user 'fyodor@froth.ly' appears to be the common actor in these activities, indicating a pattern of document interaction and search within the SharePoint environment. This data could be useful for understanding user behavior and activity patterns within</div><div id='B_LIZsfqem'><div style='color: gray;'>[CallElement] Get 4 events from the o365_management_activity_flat_tcook table.</div></div><div id='B__ALu9tlg'>The query successfully retrieved 4 events from the 'o365_management_activity_flat_tcook' table. The data includes various details such as 'ClientIP', 'CreationTime', 'EventSource', and 'Operation', among others. All events are related to SharePoint activities, with three events involving file previews and one involving a search query. The user 'fyodor@froth.ly' appears to be the common actor in these activities, indicating a pattern of document interaction and search within the SharePoint environment. This data could be useful for understanding user behavior and activity patterns within the organization's SharePoint usage.</div><div id='B_5eEh3YNw'>fetching data</div><div id='B_A0JvvqYK'>SELECT * FROM `client_demos`.`botsv3`.`o365_management_activity_flat_tcook` LIMIT 4</div><div id='B_vDJ8ToI9'><div style='background: #f0f0f0; padding: 5px; margin: 5px 0;'>📊 DataFrame: B_vDJ8ToI9 (shape: 4 x 25)</div></div></div></div>
# <LouieAI Notebook Interface | Session: Active | History: 5 responses | Traces: Disabled | Latest: 4 text, 1 dataframe>

# %% [markdown]
# ## Let's Vibe: Composing via DataFrames

# %%
lui("""

Get 100 events from databricks o365_management_activity_flat_tcook

""")
# Out:
# <div style='border: 1px solid #ddd; padding: 15px; border-radius: 5px;'><h4 style='margin-top: 0;'>🤖 LouieAI Response</h4><div style='font-size: 0.8em; color: #666; margin-bottom: 10px;'>Thread: <code>D_AmY9ZbuyZ7XjBYPmM_I6</code> | Time: 17.0s</div><div style='margin-top: 10px;'><div id='B__cNwlSv_'>The user wants to retrieve 100 events from the 'o365_management_activity_flat_tcook' table in Databricks. I will use the DatabricksAgent to perform this query.<br><br>DatabricksAgent<br>Get 100 events from the o365_management_activity_flat_tcook table.<br>I successfully retrieved 100 events from the 'o365_management_activity_flat_tcook' table in Databricks. The data includes a variety of details such as 'ClientIP', 'CreationTime', 'EventSource', and 'Operation'. These events are primarily related to SharePoint activities, including file previews, modifications, uploads, and search queries. The user 'fyodor@froth.ly' frequently appears in these activities, indicating a consistent pattern of document interaction and search within the SharePoint environment. This dataset provides valuable insights into user behavior and activity patterns, which can be instrumental in understanding and optimizing the organization's SharePoint usage. If you need</div><div id='B_aF6HjLvW'><div style='color: gray;'>[CallElement] Get 100 events from the o365_management_activity_flat_tcook table.
# </div></div><div id='B_cbAhPIB1'>The query successfully retrieved 100 events from the 'o365_management_activity_flat_tcook' table. The data encompasses a wide range of details, including 'ClientIP', 'CreationTime', 'EventSource', and 'Operation', among others. The events are predominantly related to SharePoint activities, with various operations such as file previews, modifications, uploads, and search queries. Notably, the user 'fyodor@froth.ly' frequently appears in these activities, suggesting a consistent pattern of document interaction and search within the SharePoint environment. This comprehensive dataset provides valuable insights into user behavior and activity patterns, which can be instrumental in understanding and optimizing the organization's SharePoint usage.</div><div id='B_SaRMgt7B'>fetching data</div><div id='B_oNk83E31'>SELECT * FROM `client_demos`.`botsv3`.`o365_management_activity_flat_tcook` LIMIT 100</div><div id='B_oLjmwcPL'><div style='background: #f0f0f0; padding: 5px; margin: 5px 0;'>📊 DataFrame: B_oLjmwcPL (shape: 100 x 25)</div></div></div></div>
# <LouieAI Notebook Interface | Session: Active | History: 6 responses | Traces: Disabled | Latest: 4 text, 1 dataframe>

# %%
df_id = next(e["id"] for e in reversed(lui.elements) if e.get("type") == "dataframe")
print("df_id", df_id)

lui(f"""Draw a graph using any column interesting for investigations from df {df_id}""")
# Out:
# <div style='border: 1px solid #ddd; padding: 15px; border-radius: 5px;'><h4 style='margin-top: 0;'>🤖 LouieAI Response</h4><div style='font-size: 0.8em; color: #666; margin-bottom: 10px;'>Thread: <code>D_AmY9ZbuyZ7XjBYPmM_I6</code> | Time: 29.4s</div><div style='margin-top: 10px;'><div id='B_T9C4PY1g'>To draw a graph using an interesting column from the dataframe B_oLjmwcPL, I need to identify columns that could reveal meaningful relationships or patterns. Given the context of SharePoint activities, columns like 'UserId', 'Operation', and 'SiteUrl' might be interesting for investigation. I will create a graph using these columns to visualize user interactions with different operations on various sites.<br><br>Plan:<br>1. Identify relevant columns for graph creation.<br>2. Use the GraphAgent to create a graph using the selected columns.<br>3. Visualize the graph to reveal patterns or insights.<br><br>GraphAgent<br>Create a graph using dataframe B_oLjmwcPL with columns UserId, Operation, and SiteUrl.The graph has been successfully created using the dataframe B_oLjmwcPL with the columns 'UserId', 'Operation', and 'SiteUrl'. This graph visualizes user interactions with different operations on various SharePoint and OneDrive sites. Nodes represent unique UserIds and SiteUrls, while edges represent the operations performed by users on these sites. This visualization can help in understanding user behavior patterns and site usage, providing insights into how different users interact with the Frothly SharePoint environment. If you need further analysis or</div><div id='B_hydnmWLk'><div style='color: gray;'>[CallElement] Create a graph using dataframe B_oLjmwcPL with columns UserId, Operation, and SiteUrl.</div></div><div id='B_4Ou41dbW'>The graph has been successfully created using the specified dataframe B_oLjmwcPL with the columns UserId, Operation, and SiteUrl. The graph consists of nodes and edges, where nodes represent unique UserIds and SiteUrls, and edges represent the operations performed by users on these sites. The data reveals various user activities across different SharePoint and OneDrive sites, highlighting operations such as file access, modification, and uploads. This visualization can help in understanding user behavior patterns and site usage, providing insights into how different users interact with the Frothly SharePoint environment.</div><div id='B_hcJRRulF'><div style="margin: 10px 0;"><iframe src="https:////hub.graphistry.com/graph/graph.html?dataset=768e117c139e4e37b823a57b54bf4a56" width="100%" height="600" style="border: 1px solid #ddd; border-radius: 5px;"></iframe><div style="text-align: center; margin-top: 5px;"><a href="https:////hub.graphistry.com/graph/graph.html?dataset=768e117c139e4e37b823a57b54bf4a56" target="_blank" style="color: #0066cc; text-decoration: none;">🔗 Open graph in new tab</a></div></div></div><div id='B_OCD7URJK'>GraphAgent hypergraph<br>```python<br>graphistry.hypergraph(df, params={'entity_types': ['UserId', 'Operation', 'SiteUrl'], 'direct': True})<br>```</div></div></div>
# <LouieAI Notebook Interface | Session: Active | History: 7 responses | Traces: Disabled | Latest: 3 text>

# %% [markdown]
# # Prompt Templates

# %% [markdown]
# ### Reuse prompts as template files
#
# Prompt template files and TODO/plan files are key to quickly using agents, having them do long runs, and increasing how much the AI manages itself.
#
# Likewise, instead of manually editing plans, this helps enable you to tell the AI how to do that for you. As templates get more advanced, self-modifying plans become key.

# %%
lui_template = new_thread()

lui_template("Repeat this out: The best jokes are about 19th century scientists")

lui_template.thread_id
# Out:
# <div style='border: 1px solid #ddd; padding: 15px; border-radius: 5px;'><h4 style='margin-top: 0;'>🤖 LouieAI Response</h4><div style='font-size: 0.8em; color: #666; margin-bottom: 10px;'>Thread: <code>D_N8vGZCqIDAyFJHp6qAFm</code> | Time: 3.8s</div><div style='margin-top: 10px;'><div id='B_fHHuaxG7'>The best jokes are about </div></div></div>
# 'D_N8vGZCqIDAyFJHp6qAFm'

# %%
lui_joke = new_thread()

lui_joke(f"Read dthread {lui_template.thread_id}, and only after, make a joke about it")
# Out:
# <div style='border: 1px solid #ddd; padding: 15px; border-radius: 5px;'><h4 style='margin-top: 0;'>🤖 LouieAI Response</h4><div style='font-size: 0.8em; color: #666; margin-bottom: 10px;'>Thread: <code>D__Pzwzo6_f8WewJZVRxr0</code> | Time: 12.0s</div><div style='margin-top: 10px;'><div id='B_MVb051VP'>I need to read the specified dthread first to understand its content before making a joke about it.<br>NotebookAgent<br>read dthread D_N8vGZCqIDAyFJHp6qAFmFinal Answer: The dthread humorously suggests that the best jokes are about 19th century scientists. So here's a joke for you: Why did the 19th century scientist always carry a barometer? Because he couldn't resist measuring up to the</div><div id='B_w_GPIsB0'><div style='color: gray;'>[CallElement] read dthread D_N8vGZCqIDAyFJHp6qAFm</div></div><div id='B_x8eWLZWw'><notebook id="D_N8vGZCqIDAyFJHp6qAFm"><br>  <cells><br>    <cell id="B_jG8i_UT0" agent="LouieAgent" last_run_id="None"><br>      <inputs><br>        <element type="TextElement"> | Markdown: </element><br>      </inputs><br>      <outputs/><br>    </cell><br>    <cell id="B_UnWPokPS" agent="LouieAgent" last_run_id="R_GA50ulUL36fFQzSNqsef"><br>      <inputs><br>        <element type="TextElement"> | Markdown: Repeat this out: The best jokes are about 19th century scientists</element><br>      </inputs><br>      <outputs><br>        <element type="TextElement"> | Markdown: The best jokes are about 19th century scientists!</element><br>      </outputs><br>      <run id="R_GA50ulUL36fFQzSNqsef" state="Done" run_type="LouieAgent"><br>        <traces><br>          <trace level="Level.INFO">LouieAgent::runner</trace><br>          <trace level="Level.DEBUG">Input text:::Repeat this out: The best jokes are about 19th century scientists</trace><br>          <trace level="Level.DEBUG">Reading chat history. (is_prepared: True)</trace><br>          <trace level="Level.DEBUG">...</trace><br>          <trace level="Level.INFO">Louie output text: The best jokes are about 19th century scientists!</trace><br>        </traces><br>      </run><br>    </cell><br>  </cells><br></notebook></div><div id='B_byENWFcS'>The notebook with the ID 'D_N8vGZCqIDAyFJHp6qAFm' contains a humorous statement emphasizing that the best jokes are about 19th century scientists. This suggests a playful engagement with historical scientific figures, possibly highlighting their quirks or contributions in a light-hearted manner. The content reflects a blend of humor and historical reference, which can be an engaging way to connect with audiences interested in both science and comedy.</div></div></div>
# <LouieAI Notebook Interface | Session: Active | History: 1 responses | Traces: Disabled | Latest: 3 text>

# %%
print(lui_joke.text)
# Out:
# I need to read the specified dthread first to understand its content before making a joke about it.
# NotebookAgent
# read dthread D_N8vGZCqIDAyFJHp6qAFmFinal Answer: The dthread humorously suggests that the best jokes are about 19th century scientists. So here's a joke for you: Why did the 19th century scientist always carry a barometer? Because he couldn't resist measuring up to the
